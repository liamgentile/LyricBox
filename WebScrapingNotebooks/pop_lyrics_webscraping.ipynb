# %% [markdown]
# # In this notebook I use my dictionary of pop artists mapped to songs in order to scrape the song lyrics for each song and artist.

# %% [markdown]
# I'll start by importing the required packages.

# %%
import requests
from time import sleep
import csv
import json
import re
import pandas as pd
import numpy as np

# %% [markdown]
# ## Formatting, Editing, Filtering for Lyric Webscraping

# %%
# file containing artists - songs mapping
folk_songs_json = "Pop-Artists-Songs-Mapping.json"
folk_songs_dict = {}

with open(folk_songs_json) as file:
    pop_songs_dict = json.load(file)

# %%
# checking the keys (artist names)
pop_songs_dict.keys()
# Out:
# dict_keys(['Taylor Swift', 'Lady Gaga', 'Beyonce (Beyoncé)', 'Ariana Grande', 'Justin Bieber', 'Katy Perry', 'Michael Jackson', 'Billie Eilish', 'Madonna', 'Selena Gomez', 'Rihanna', 'Miley Cyrus', 'Dua Lipa', 'Demi Lovato', 'Lana Del Rey', 'Bruno Mars', 'Britney Spears', 'Ed Sheeran', 'Shawn Mendes', 'Adele', 'Halsey', 'Justin Timberlake', 'Maroon 5', 'Pink (P!nk)', 'Sam Smith', 'One Direction', 'Lorde', 'Ellie Goulding', 'Beach Boys', 'Elton John', 'The Beatles', 'Ava Max', 'Harry Styles', 'Sia', 'Christina Aguilera', 'Khalid', 'Imagine Dragons', 'Backstreet Boys', 'Jennifer Lopez', 'Janet Jackson', 'Cher', 'Whitney Houston', 'Jackson 5', 'Prince', 'Tina Turner', 'Kelly Clarkson', "'N Sync", 'Gwen Stefani', 'Black Eyed Peas', 'Jonas Brothers', 'Usher', 'Sheryl Crow', 'New Kids On The Block', 'Phil Collins', 'Fergie', 'Amy Winehouse', 'ABBA', 'Jessica Simpson', 'Nick Jonas', 'George Michael', 'Avril Lavigne', 'John Mayer', 'Kesha (Ke$ha)', 'Toto', 'Lizzo', 'Carly Rae Jepsen', 'Twenty One Pilots', 'Fifth Harmony', 'Rob Thomas', 'The Chainsmokers', 'James Blunt', 'Natasha Bedingfield', 'Charlie Puth', 'Rita Ora', 'Charli XCX', 'Fun.', 'Niall Horan', 'Lewis Capaldi', 'DNCE', 'Lukas Graham', 'Tove Lo', 'James Arthur', 'Banks', 'Jessie Reyez', 'Maggie Rogers', 'Mabel', 'Kiiara', 'Ella Mai', 'Anne-Marie', 'Alessia Cara', 'Julia Michaels', 'Tori Kelly', 'Solange Knowles'])

# %% [markdown]
# Now I have to reformat the artist names in the dictionary to the url appropriate names...

# %%
pop_artists_for_link = ['taylorswift', 'ladygaga', 'knowles', 'arianagrande', 'justinbieber',
                    'katyperry', 'jackson', 'billieeilish', 'madonna', 'selenagomez',
                    'rihanna', 'mileycyrus', 'dualipa', 'demilovato', 'lanadelrey',
                    'brunomars', 'spears', 'edsheeran', 'shawnmendes', 'adele', 
                    'halsey', 'timberlake', 'maroon5', 'pink', 
                    'samsmith', 'onedirection', 'lorde', 'elliegoulding', 'beachboys', 
                    'john', 'beatles', 'avamax', 'harrystyles', 'sia', 'aguilera',
                    'khalid', 'imaginedragons', 'bsb', 'lopez', 'janete',
                    'cher', 'houston', 'jackson5', 'prince', 'turner', 'clarkson',
                    "nsync", 'gwenstefani', 'blackeyedpeas', 'jonasbrothers', 'usher',
                    'crow', 'newkids', 'collins',
                    'fergie', 'amywinehouse', 'abba', 'simpson', 'nickjonas', 'michael',
                    'lavigne', 'mayer', 'keha', 'toto', 'lizzo', 
                    'carlyraejepsen', 'twentyonepilots', 'fifthharmony', 'robthomas',
                    'chainsmokers', 'jamesblunt', 'bedingfieldn', 'charlieputh', 
                    'ritaora', 'charlixcx', 'fun', 'niallhoran', 'lewiscapaldi',
                    'dnce', 'lukasgraham', 'tovelo', 'jamesarthur', 'banks', 'jessiereyez',
                    'maggierogers', 'mabel', 'avamax', 'kiiara', 'ellamai', 'annemarie',
                    'alessiacara', 'juliamichaels', 'torikelly', 'knowless']

  
# changing keys of dictionary to formatting for link
pop_songs_dict = dict(zip(pop_artists_for_link, list(pop_songs_dict.values())))
pop_songs_dict.keys()
# Out:
# dict_keys(['taylorswift', 'ladygaga', 'knowles', 'arianagrande', 'justinbieber', 'katyperry', 'jackson', 'billieeilish', 'madonna', 'selenagomez', 'rihanna', 'mileycyrus', 'dualipa', 'demilovato', 'lanadelrey', 'brunomars', 'spears', 'edsheeran', 'shawnmendes', 'adele', 'halsey', 'timberlake', 'maroon5', 'pink', 'samsmith', 'onedirection', 'lorde', 'elliegoulding', 'beachboys', 'john', 'beatles', 'avamax', 'harrystyles', 'sia', 'aguilera', 'khalid', 'imaginedragons', 'bsb', 'lopez', 'janete', 'cher', 'houston', 'jackson5', 'prince', 'turner', 'clarkson', 'nsync', 'gwenstefani', 'blackeyedpeas', 'jonasbrothers', 'usher', 'crow', 'newkids', 'collins', 'fergie', 'amywinehouse', 'abba', 'simpson', 'nickjonas', 'michael', 'lavigne', 'mayer', 'keha', 'toto', 'lizzo', 'carlyraejepsen', 'twentyonepilots', 'fifthharmony', 'robthomas', 'chainsmokers', 'jamesblunt', 'bedingfieldn', 'charlieputh', 'ritaora', 'charlixcx', 'fun', 'niallhoran', 'lewiscapaldi', 'dnce', 'lukasgraham', 'tovelo', 'jamesarthur', 'banks', 'jessiereyez', 'maggierogers', 'mabel', 'kiiara', 'ellamai', 'annemarie', 'alessiacara', 'juliamichaels', 'torikelly'])

# %% [markdown]
# In the following nested for loop I reformat the song names (removing punctuation and symbols) in order for the song name to be appropriately formatted for looping through the urls.

# %%
for key in pop_songs_dict:
    
    pop_songs = []
    
    for x in pop_songs_dict[key]:
        x = x.replace(" ", "").lower()
        x = x.replace("(", "")
        x = x.replace(")", "")
        x = x.replace(".", "")
        x = x.replace(",", "")
        x = x.replace("'", "")
        x = x.replace("/", "")
        x = x.replace("?", "")
        x = x.replace("#", "")
        x = x.replace("$", "s")
        x = x.replace("&", "and")
        x = x.replace(":", "")
        x = x.replace("-", "")
        
        # if statement to prevent duplicate song names from being added
        if x not in pop_songs:
                pop_songs.append(x)
            
        
    pop_songs_dict[key] = pop_songs

# %% [markdown]
# Quickly taking a look that the formatting looks right...

# %%
pop_songs_dict
# Out:
# {'taylorswift': ['timmcgraw',
#   'picturetoburn',
#   'teardropsonmyguitar',
#   'aplaceinthisworld',
#   'coldasyou',
#   'theoutside',
#   'tiedtogetherwithasmile',
#   'staybeautiful',
#   'shouldvesaidno',
#   'maryssongohmymymy',
#   'oursong',
#   'imonlymewhenimwithyoudeluxeedition',
#   'invisibledeluxeedition',
#   'aperfectlygoodheartdeluxeedition',
#   'lastchristmas',
#   'christmaseswhenyouweremine',
#   'santababy',
#   'silentnight',
#   'christmasmustbesomethingmore',
#   'whitechristmas',
#   'jumpthenfallplatinumedition',
#   'untouchableplatinumedition',
#   'foreverandalwayspianoversionplatinumedition',
#   'comeinwiththerainplatinumedition',
#   'superstarplatinumedition',
#   'theothersideofthedoorplatinumedition',
#   'fearless',
#   'fifteen',
#   'lovestory',
#   'heystephen',
#   'whitehorse',
#   'youbelongwithme',
#   'breathe',
#   'tellmewhy',
#   'yourenotsorry',
#   'thewayilovedyou',
#   'foreverandalways',
#   'thebestday',
#   'change',
#   'mine',
#   'sparksfly',
#   'backtodecember',
#   'speaknow',
#   'dearjohn',
#   'mean',
#   'thestoryofus',
#   'nevergrowup',
#   'enchanted',
#   'betterthanrevenge',
#   'innocent',
#   'haunted',
#   'lastkiss',
#   'longlive',
#   'oursdeluxeeditionbonustrack',
#   'ifthiswasamoviedeluxeeditionbonustrack',
#   'supermandeluxeeditionbonustrack',
#   'stateofgrace',
#   'red',
#   'treacherous',
#   'iknewyouweretrouble',
#   'alltoowell',
#   '22',
#   'ialmostdo',
#   'weareneverevergettingbacktogether',
#   'staystaystay',
#   'thelasttime',
#   'holyground',
#   'sadbeautifultragic',
#   'theluckyone',
#   'everythinghaschanged',
#   'starlight',
#   'beginagain',
#   'themomentiknewdeluxeeditionbonustrack',
#   'comebackbeheredeluxeeditionbonustrack',
#   'girlathomedeluxeeditionbonustrack',
#   'welcometonewyork',
#   'blankspace',
#   'style',
#   'outofthewoods',
#   'allyouhadtodowasstay',
#   'shakeitoff',
#   'iwishyouwould',
#   'badblood',
#   'wildestdreams',
#   'howyougetthegirl',
#   'thislove',
#   'iknowplaces',
#   'clean',
#   'wonderlanddeluxeeditionbonustrack',
#   'youareinlovedeluxeeditionbonustrack',
#   'newromanticsdeluxeeditionbonustrack',
#   'readyforit',
#   'endgame',
#   'ididsomethingbad',
#   'dontblameme',
#   'delicate',
#   'lookwhatyoumademedo',
#   'soitgoes',
#   'gorgeous',
#   'getawaycar',
#   'kingofmyheart',
#   'dancingwithourhandstied',
#   'dress',
#   'thisiswhywecanthavenicethings',
#   'callitwhatyouwant',
#   'newyearsday',
#   'iforgotthatyouexisted',
#   'cruelsummer',
#   'lover',
#   'theman',
#   'thearcher',
#   'ithinkheknows',
#   'missamericanaandtheheartbreakprince',
#   'paperrings',
#   'corneliastreet',
#   'deathbyathousandcuts',
#   'londonboy',
#   'soonyoullgetbetter',
#   'falsegod',
#   'youneedtocalmdown',
#   'afterglow',
#   'me!',
#   'itsnicetohaveafriend',
#   'daylight',
#   'the1',
#   'cardigan',
#   'thelastgreatamericandynasty',
#   'exile',
#   'mytearsricochet',
#   'mirrorball',
#   'seven',
#   'august',
#   'thisismetrying',
#   'illicitaffairs',
#   'invisiblestring',
#   'madwoman',
#   'epiphany',
#   'betty',
#   'peace',
#   'hoax',
#   'thelakesdeluxeeditionbonustrack',
#   'willow',
#   'champagneproblems',
#   'goldrush',
#   'tisthedamnseason',
#   'tolerateit',
#   'nobodynocrime',
#   'happiness',
#   'dorothea',
#   'coneyisland',
#   'ivy',
#   'cowboylikeme',
#   'longstoryshort',
#   'marjorie',
#   'closure',
#   'evermore',
#   'rightwhereyouleftmedeluxeeditionbonustrack',
#   'itstimetogodeluxeeditionbonustrack',
#   'fearlesstaylorsversion',
#   'fifteentaylorsversion',
#   'lovestorytaylorsversion',
#   'heystephentaylorsversion',
#   'whitehorsetaylorsversion',
#   'youbelongwithmetaylorsversion',
#   'breathetaylorsversion',
#   'tellmewhytaylorsversion',
#   'yourenotsorrytaylorsversion',
#   'thewayilovedyoutaylorsversion',
#   'foreverandalwaystaylorsversion',
#   'thebestdaytaylorsversion',
#   'changetaylorsversion',
#   'jumpthenfalltaylorsversion',
#   'untouchabletaylorsversion',
#   'foreverandalwayspianoversiontaylorsversion',
#   'comeinwiththeraintaylorsversion',
#   'superstartaylorsversion',
#   'theothersideofthedoortaylorsversion',
#   'todaywasafairytaletaylorsversion',
#   'youallovermetaylorsversionfromthevault',
#   'mrperfectlyfinetaylorsversionfromthevault',
#   'wewerehappytaylorsversionfromthevault',
#   'thatswhentaylorsversionfromthevault',
#   'dontyoutaylorsversionfromthevault',
#   'byebyebabytaylorsversionfromthevault',
#   'readyforitbloodpop®remix',
#   'aintnothingboutyou',
#   'allbecauseofellen',
#   'allnightdiner',
#   'amireadyforlove',
#   'americanboy',
#   'americangirl',
#   'angelina',
#   'babydontyoubreakmyheartslow',
#   'backtodecemberapologizeyourenotsorryfrom"speaknowworldtourlive"album',
#   'badbloodremix',
#   'beautifuleyes',
#   'beautifulghostsfrom"cats"soundtrack',
#   'beingwithmybaby',
#   'bettedaviseyes',
#   'betteroff',
#   'brandnewworld',
#   'breathlessfrom"hopeforhaitinow"compilation',
#   'broughtupthatway',
#   'bytheway',
#   'canigowithyou',
#   'cantstoplovingyou',
#   'checkoutthisview',
#   'christmastreefarm',
#   'closesttoacowboy',
#   'crazierfrom"hannahmontanathemovie"soundtrack',
#   'crossmyheart',
#   'darkbluetennessee',
#   'didntthey',
#   'donthatemeforlovingyou',
#   'downcametherain',
#   'dropsofjupiterfrom"speaknowworldtourlive"',
#   'eyesopenfrom"thehungergames"soundtrack',
#   'fallbackonyou',
#   'firefly',
#   'foryou',
#   'gracie',
#   'honeybaby',
#   'hopelesslydevotedtoyou',
#   'idontwannaliveforeverfrom"fiftyshadesdarker"soundtrack',
#   'iheart',
#   'iknewyouweretroubleremix',
#   'iknowwhatiwant',
#   'iusedtofly',
#   'iwantyoubackfrom"speaknowworldtourlive"album',
#   'iwishedonaplane',
#   'idlie',
#   'inthepouringrain',
#   'justsouthofknowingwhy',
#   'letsgobattle',
#   'liveforthelittlethings',
#   'longtimecoming',
#   'lookatyoulikethat',
#   'lookwhatyoumademedomusicvideoversion',
#   'lovestorytaylorsversionelviraremix',
#   'lovetheyhaventthoughtofyet',
#   'lovetolose',
#   'loverfirstdanceremix',
#   'loverremix',
#   'luckyyou',
#   'macavityfrom"cats"soundtrack',
#   'madeupyou',
#   'makingupforlostlove',
#   'mandolin',
#   'matches',
#   'meandbritney',
#   'monologuesonglalala',
#   'mycure',
#   'myturntobeme',
#   'nashville',
#   'needyounow',
#   'neverfade',
#   'nevermind',
#   'onething',
#   'onewayticket',
#   'onlytheyoungfrom"taylorswiftmissamericana"soundtrack',
#   'ourlastnight',
#   'perfecthaveiloved',
#   'permanentmarker',
#   'pointofview',
#   'revenge',
#   'riptide',
#   'ronan',
#   'run',
#   'safeandsoundfrom"thehungergames"soundtrack',
#   'samegirl',
#   'september',
#   'smokeyblacknights',
#   'spinningaround',
#   'stupidboy',
#   'sugar',
#   'sweetescape',
#   'sweetteaandgodsgraces',
#   'sweeterthanfictionfrom"onechance"soundtrack',
#   'tellme',
#   'tendollarsandasixpack',
#   'tennessee',
#   'thatslife',
#   'thatswhen',
#   'thediaryofme',
#   'theresyourtrouble',
#   'thirteenblockscantcallitlove',
#   'thishereguitar',
#   'thisisreallyhappening',
#   'thugstory',
#   'tilbradpittcomesalong',
#   'todaywasafairytalefrom"valentinesday"soundtrack',
#   'undermyhead',
#   'vivalavida',
#   'waitforme',
#   'wewerehappy',
#   'welcomedistraction',
#   'whatdoyousay',
#   'whattowear',
#   'whoivealwaysbeen',
#   'writingsongsaboutyou',
#   'youdo',
#   'youranything',
#   'yourface'],
#  'ladygaga': ['somethingcrazy',
#   'wishyouwerehere',
#   'nofloods',
#   'redandblue',
#   'words',
#   'justdance',
#   'lovegame',
#   'paparazzi',
#   'beautifuldirtyrich',
#   'ehehnothingelseicansay',
#   'pokerface',
#   'thefame',
#   'moneyhoney',
#   'againagain',
#   'boysboysboys',
#   'browneyes',
#   'summerboy',
#   'ilikeitroughitunesuseuropeanandaustralianeditions',
#   'retrodancefreakaustralianandjapanesebonustrack',
#   'badromance',
#   'alejandro',
#   'monster',
#   'speechless',
#   'danceinthedark',
#   'telephone',
#   'sohappyicoulddie',
#   'teeth',
#   'marrythenight',
#   'bornthisway',
#   'governmenthooker',
#   'judas',
#   'americano',
#   'hair',
#   'scheiße',
#   'bloodymary',
#   'badkids',
#   'highwayunicornroadtolove',
#   'heavymetallover',
#   'electricchapel',
#   'youandi',
#   'theedgeofglory',
#   'bornthiswayjostandnaafremixukbonustrack',
#   'blackjesus+amenfashionspecialeditionbonustrack',
#   'fashionofhislovespecialeditionbonustrack',
#   'thequeenspecialeditionbonustrack',
#   'whitechristmas',
#   'orangecoloredsky',
#   'auraburqa',
#   'venus',
#   'guy',
#   'sexxxdreams',
#   'jewelsndrugs',
#   'manicure',
#   'dowhatuwant',
#   'artpop',
#   'swine',
#   'donatella',
#   'fashion!',
#   'maryjaneholland',
#   'dope',
#   'gypsy',
#   'applause',
#   'anythinggoes',
#   'cheektocheek',
#   'dontwaittoolong',
#   'icantgiveyouanythingbutlove',
#   'natureboy',
#   'goodygoody',
#   'evrytimewesaygoodbye',
#   'firefly',
#   'iwontdance',
#   'theyalllaughed',
#   'lushlife',
#   'sophisticatedlady',
#   'letsfacethemusicanddance',
#   'butbeautiful',
#   'itdontmeanathingifitaintgotthatswing',
#   'bangbangmybabyshotmedownitunesbonustrack',
#   'onacleardayyoucanseeforevertargetbonustrack',
#   'bewitchedbotheredandbewilderedtargetbonustrack',
#   'theladysinlovewithyouhsnbonustrack',
#   'theladyisatramphsnbonustrack',
#   'diamondheart',
#   'ayo',
#   'joanne',
#   'johnwayne',
#   'dancinincircles',
#   'perfectillusion',
#   'millionreasons',
#   'sinnersprayer',
#   'cometomama',
#   'heygirl',
#   'angeldown',
#   'grigiogirlsdeluxeeditionbonustrack',
#   'justanotherdaydeluxeeditionbonustrack',
#   'angeldownworktapedeluxeeditionbonustrack',
#   'millionreasonsworktapejapanesebonustrack',
#   'blackeyes',
#   'somewhereovertherainbowdialogue',
#   'fabulousfrenchdialogue',
#   'lavieenrose',
#   'illwaitforyoudialogue',
#   'maybeitstime',
#   'parkinglotdialogue',
#   'alibi',
#   'trustme',
#   'shallow',
#   'firststoparizonadialogue',
#   'musictomyeyes',
#   'digginmygrave',
#   'iloveyoudialogue',
#   'alwaysrememberusthisway',
#   'unbelievabledialogue',
#   'howdoyouhearitdialogue',
#   'lookwhatifound',
#   'memphisdialogue',
#   'healme',
#   'idontknowwhatloveis',
#   'vowsdialogue',
#   'isthatalright',
#   'snldialogue',
#   'whydidyoudothat',
#   'hairbodyface',
#   'scene98dialogue',
#   'beforeicry',
#   'toofargone',
#   'twelvenotesdialogue',
#   'illneverloveagainfilmversion',
#   'illneverloveagainextendedversion',
#   'alice',
#   'stupidlove',
#   'rainonme',
#   'freewoman',
#   'funtonight',
#   '911',
#   'plasticdoll',
#   'sourcandy',
#   'enigma',
#   'replay',
#   'sinefromabove',
#   '1000doves',
#   'babylon',
#   'lovemerighttargetbonustrack',
#   '1000dovespianodemotargetbonustrack',
#   'animal',
#   'babyitscoldoutside',
#   'bennyandthejets',
#   'blueberrykisses',
#   'brooklynnights',
#   'cakelikeladygaga',
#   'captivated',
#   'changingskies',
#   'christmastree',
#   'davidbowietribute',
#   'dirtyicecream',
#   'discoheaven',
#   'dowhatuwantdjwsremix',
#   'dowhatuwantremix',
#   'earthquake',
#   'electrickiss',
#   'fancypants',
#   'fashionfrom"confessionsofashopaholic"soundtrack',
#   'fever',
#   'filthypop',
#   'fooledmeagainhonesteyes',
#   'fountainoftruth',
#   'frankensteined',
#   'freakshow',
#   'futurelove',
#   'glamourzombie',
#   'glitterandgrease',
#   'greatest',
#   'hellohellofrom"gnomeoandjuliet"soundtrack',
#   'herewegoagain',
#   'hollywood',
#   'iwannabewithyou',
#   'iwantyourlove',
#   'imagine',
#   'ink',
#   'joannewheredoyouthinkyouregoinpianoversion',
#   'kaboom',
#   'kandylife',
#   'kingofpain',
#   'letlovedown',
#   'livingontheradio',
#   'lovesickgirl',
#   'masterheartbreaker',
#   'musicland',
#   'newyork',
#   'newyorknewyork',
#   'noway',
#   'nothinonbuttheradio',
#   'ohwell',
#   'oniongirl',
#   'optimist',
#   'outofcontrol',
#   'outofcontrolremix',
#   'pantyparty',
#   'papergangsta',
#   'partynauseous',
#   'partynauseousdemo',
#   'popatemyheartinterlude',
#   'poshlife',
#   'princessdie',
#   'redflame',
#   'reelcool',
#   'reloaded',
#   'retrophysical',
#   'retrosexual',
#   'ribbons',
#   'rockshow',
#   'screamloud',
#   'secondtimearound',
#   'sexyugly',
#   'shakeurkitty',
#   'sometimes',
#   'stache',
#   'starstruck',
#   'stuckonfuckinyou',
#   'superlover',
#   'superstar',
#   'takeyouout',
#   'thecure',
#   'thegreatestthing',
#   'thesoundofmusictribute',
#   'thenyoudloveme',
#   'tillithappenstoyoufrom"thehuntingground"soundtrack',
#   'trigger',
#   'vanity',
#   'vivalavida',
#   'weareplastic',
#   'wecouldbelovers',
#   'winterwonderland',
#   'wonderful',
#   'wunderland',
#   'yayha',
#   'youreallmylittlemonstersfrom"thesimpsons"soundtrack',
#   'yourfreakincar',
#   'yoursong'],
#  'knowles': ['crazyinlove',
#   'naughtygirl',
#   'babyboy',
#   'hiphopstar',
#   'bewithyou',
#   'memyselfandi',
#   'yes',
#   'signs',
#   'speechless',
#   'thatshowyoulikeit',
#   'closerigettoyou',
#   'dangerouslyinlove2',
#   'beyonceinterlude',
#   'giftfromvirgo',
#   '03bonnieandclyde',
#   'workitout',
#   'daddy',
#   'fightingtemptations',
#   'fever',
#   'everythingido',
#   'swinglowsweetchariot',
#   'hestilllovesme',
#   'timetocomehome',
#   'summertimewpdiddy',
#   'déjàvu',
#   'getmebodied',
#   'sugamama',
#   'upgradeu',
#   'ringthealarm',
#   'kittykat',
#   'freakumdress',
#   'greenlight',
#   'irreplaceable',
#   'resentment',
#   'creolejapanbonustrack',
#   'checkonit',
#   'lostyominditunespreorderexclusive',
#   'encoreforthefansbonustrack',
#   'listenhiddentrack',
#   'getmebodiedextendedremixbonustrack',
#   'beautifulliar',
#   'welcometohollywood',
#   'flawsandall',
#   'ifeuasianaustralianedition',
#   'stillinlovekissingyou',
#   'worldwidewomenhiddentrack',
#   'amorgitano',
#   'oyelistenspanishversion',
#   'irreemplazableirreplaceablespanishversion',
#   'belloembusterobeautifulliarspanishversion',
#   'beautifulliarremix',
#   'beautifulliarspanglishversion',
#   'irreemplazablenortenaremix',
#   'ifiwereaboy',
#   'halo',
#   'disappear',
#   'brokenheartedgirl',
#   'avemaria',
#   'smashintoyou',
#   'satellites',
#   'thatswhyyourebeautiful',
#   'savetheherojapanbonustrack',
#   'siyofueraunchicospainitunesbonustrack',
#   'singleladiesputaringonit',
#   'radio',
#   'diva',
#   'sweetdreams',
#   'videophone',
#   'hello',
#   'ego',
#   'scaredoflonely',
#   'whydontyoulovemejapanbonustrack',
#   'videophoneextendedremix',
#   'poison',
#   'honesty',
#   '1+1',
#   'icare',
#   'imissyou',
#   'bestthingineverhad',
#   'party',
#   'ratherdieyoung',
#   'startover',
#   'loveontop',
#   'countdown',
#   'endoftime',
#   'iwashere',
#   'runtheworldgirls',
#   'dreamingjapanesebonustrack',
#   'layupundermedeluxeeditionbonustrack',
#   'schoolinlifedeluxeeditionbonustrack',
#   'danceforyoudeluxeeditionbonustrack',
#   'prettyhurts',
#   'ghosthaunted',
#   'drunkinlove',
#   'blow',
#   'noangel',
#   'yoncépartition',
#   'jealous',
#   'rocket',
#   'mine',
#   'xo',
#   'flawless',
#   'superpower',
#   'heaven',
#   'blue',
#   '711platinumeditionbonustrack',
#   'flawlessremixplatinumeditionbonustrack',
#   'drunkinloveremixplatinumeditionbonustrack',
#   'ringoffplatinumeditionbonustrack',
#   'blowremixplatinumeditionbonustrack',
#   'standingonthesunremixplatinumeditionbonustrack',
#   'prayyoucatchme',
#   'holdup',
#   'donthurtyourself',
#   'sorry',
#   '6inch',
#   'daddylessons',
#   'lovedrought',
#   'sandcastles',
#   'forward',
#   'freedom',
#   'allnight',
#   'formation',
#   'sorryoriginaldemodeluxeeditionbonustrack',
#   'summer',
#   'apeshit',
#   'boss',
#   'nice',
#   '713',
#   'friends',
#   'heardaboutus',
#   'blackeffect',
#   'lovehappy',
#   'welcomehomecominglive',
#   'crazyinlovehomecominglive',
#   'freedomhomecominglive',
#   'lifteveryvoiceandsinghomecominglive',
#   'formationhomecominglive',
#   'somuchdamnswaginterludehomecominglive',
#   'sorryhomecominglive',
#   'kittykathomecominglive',
#   'bowdownhomecominglive',
#   'ibeenonhomecominglive',
#   'drunkinlovehomecominglive',
#   'divahomecominglive',
#   'flawlessfeelingmyselfhomecominglive',
#   'topoffhomecominglive',
#   '711homecominglive',
#   'bugaboorollcallinterludehomecominglive',
#   'partyhomecominglive',
#   'donthurtyourselfhomecominglive',
#   'icarehomecominglive',
#   'partitionhomecominglive',
#   'yoncéhomecominglive',
#   'migentehomecominglive',
#   'babyboyhomecominglive',
#   'youdontlovemenononohomecominglive',
#   'holduphomecominglive',
#   'countdownhomecominglive',
#   'checkonithomecominglive',
#   'dejavuhomecominglive',
#   'thebzzzzdrumlineinterludehomecominglive',
#   'runtheworldgirlshomecominglive',
#   'losemybreathhomecominglive',
#   'saymynamehomecominglive',
#   'soldierhomecominglive',
#   'getmebodiedhomecominglive',
#   'singleladiesputaringonithomecominglive',
#   'lifteveryvoiceandsingbluesversionhomecominglive',
#   'loveontophomecominglive',
#   'shiningthankyouhomecominglive',
#   'beforeiletgohomecominglivebonustrack',
#   'ibeenonhomecominglivebonustrack',
#   'balancemufasainterlude',
#   'bigger',
#   'thestarsmufasainterlude',
#   'findyourwayback',
#   'unclescarscarinterlude',
#   'dontjealousme',
#   'dangeryoungsimbaandyoungnalainterlude',
#   'jaarae',
#   'runawayscarandyoungsimbainterlude',
#   'nile',
#   'newlessontimonpumbaaandyoungsimbainterlude',
#   'mood4eva',
#   'reunitednalaandsimbainterlude',
#   'water',
#   'brownskingirl',
#   'comehomenalainterlude',
#   'keystothekingdom',
#   'followmerafikiinterlude',
#   'already',
#   'remembermufasainterlude',
#   'otherside',
#   'warnalainterlude',
#   'mypower',
#   'surrendersimbaandscarinterlude',
#   'scar',
#   'imhomemufasasarabiandsimbainterlude',
#   'spirit',
#   'blackparadedeluxeeditionbonustrack',
#   'hesmymanleftovertrackfrom"bday"',
#   '6325792',
#   'awomanlikemefrom"pinkpanther"soundtrack',
#   'afterallissaidanddonefrom"thebestman"soundtrack',
#   'allicoulddowascryfrom"cadillacrecords"soundtrack',
#   'atlastfrom"cadillacrecords"soundtrack',
#   'backtoblackfrom"thegreatgatsby"soundtrack',
#   'backup',
#   'blackculture',
#   'bodyrock',
#   'bowdownibeenon',
#   'canyoufeelthelovetonightfrom"thelionking"2019soundtrack',
#   'cardsneverliefrom"mtvshiphoperacarmen"soundtrack',
#   'control',
#   'crazyinlovefiftyshadesofgreyversion',
#   'daddylessonsremix',
#   'diewithyou',
#   'egoremix',
#   'godblesstheusa',
#   'godmadeyoubeautiful',
#   'grownwoman',
#   'halofrom"hopeforhaitinow"compilation',
#   'haveyourwayfrom"hiswomanhiswife"soundtrack',
#   'hellolive',
#   'ibeenonremix',
#   'icanttakenomore',
#   'icareremix',
#   'idrathergoblindfrom"cadillacrecords"soundtrack',
#   'imalonenowleftovertrackfrom"iamsashafierce"',
#   'imleaving',
#   'icecreamtruck',
#   'ifiwereaboyremix',
#   'iflookscouldkillyouwouldbedeadfrom"mtvshiphoperacarmen"soundtrack',
#   'indaclub',
#   'inthisworld',
#   'irreplaceableremix',
#   'jealousremix',
#   'keepgivingyourlovetomefrom"badboysii"soundtrack',
#   'kickhimoutnextexleftovertrackfrom"bday"',
#   'moveyourbody"getmebodied"remix',
#   'naughtygirlremix',
#   'newshoespostcardleftovertrackfrom"bday"',
#   'onceinalifetimefrom"cadillacrecords"soundtrack',
#   'partitionremix',
#   'partyremix',
#   'riseupfrom"epic"soundtrack',
#   'rocleftovertrackfrom"iamsashafierce"',
#   'salud!',
#   'settle4u',
#   'shouldhavenowiknowforevertobleed',
#   'slowlove',
#   'soamazing',
#   'standingonthesun',
#   'stopsign',
#   'stopthat!from"mtvshiphoperacarmen"soundtrack',
#   'summertime',
#   'summertimeremix',
#   'thelastgreatseductionfrom"mtvshiphoperacarmen"soundtrack',
#   'tributetosteviewonderlive',
#   'waiting',
#   'whatsgoodwithyou',
#   'wishingonastarfrom"rollbounce"soundtrack',
#   'youaremyrock'],
#  'arianagrande': ['honeymoonavenue',
#   'babyi',
#   'rightthere',
#   'tattooedheart',
#   'lovinit',
#   'piano',
#   'daydreamin',
#   'theway',
#   'youllneverknow',
#   'almostisneverenough',
#   'popularsong',
#   'betterleftunsaid',
#   'thewayspanglishversion',
#   'lastchristmas',
#   'loveiseverything',
#   'snowincalifornia',
#   'santababy',
#   'intro',
#   'problem',
#   'onelasttime',
#   'whytry',
#   'breakfree',
#   'bestmistake',
#   'bemybaby',
#   'breakyourheartrightback',
#   'lovemeharder',
#   'justalittlebitofyourheart',
#   'handsonme',
#   'myeverything',
#   'bangbangdeluxeeditionbonustrack',
#   'only1deluxeeditionbonustrack',
#   'youdontknowmedeluxeeditionbonustrack',
#   'cadillacsongjapanesebonustrack',
#   'tooclosejapanesebonustrack',
#   'babyijapaneseeditionbonustrack',
#   'wititthischristmas',
#   'december',
#   'notjustonchristmas',
#   'truelove',
#   'winterthings',
#   'moonlight',
#   'dangerouswoman',
#   'bealright',
#   'intoyou',
#   'sidetoside',
#   'letmeloveyou',
#   'greedy',
#   'leavemelonely',
#   'everyday',
#   'sometimes',
#   'idontcare',
#   'baddecisionsdeluxeeditionbonustrack',
#   'touchitdeluxeeditionbonustrack',
#   'knewbetterforeverboydeluxeeditionbonustrack',
#   'thinkinboutyoudeluxeeditionbonustrack',
#   'focusjapanesebonustrack',
#   'steponuptargetbonustrack',
#   'jasonssonggaveitawaytargetbonustrack',
#   'raindropsanangelcried',
#   'blazed',
#   'thelightiscoming',
#   'rem',
#   'godisawoman',
#   'sweetener',
#   'successful',
#   'everytime',
#   'breathin',
#   'notearslefttocry',
#   'borderline',
#   'betteroff',
#   'goodnightngo',
#   'petedavidson',
#   'getwellsoon',
#   'imagine',
#   'needy',
#   'nasa',
#   'bloodline',
#   'fakesmile',
#   'badidea',
#   'makeup',
#   'ghostin',
#   'inmyhead',
#   '7rings',
#   'thankunext',
#   'breakupwithyourgirlfriendimbored',
#   'shutup',
#   '34+35',
#   'motive',
#   'justlikemagic',
#   'offthetable',
#   'sixthirty',
#   'safetynet',
#   'myhair',
#   'nasty',
#   'westside',
#   'lovelanguage',
#   'positions',
#   'obvious',
#   'pov',
#   'someonelikeudeluxeeditionbonustrack',
#   'testdrivedeluxeeditionbonustrack',
#   '34+35remixdeluxeeditionbonustrack',
#   'worstbehaviordeluxeeditionbonustrack',
#   'mainthingdeluxeeditionbonustrack',
#   '7ringsremix',
#   'alittlemorehomeworkfrom"13"soundtrack',
#   'abc',
#   'allmylovefrom"thehungergamesmockingjaypart1"soundtrack',
#   'badtoyoufrom"charliesangels"soundtrack',
#   'beautyandthebeastfrom"beautyandthebeast"soundtrack',
#   'boyfriend',
#   'boyfriendmaterial',
#   'brandnewyoufrom"13"soundtrack',
#   'dieinyourarms',
#   'doyouloveme',
#   'dontcallmeangelfrom"charliesangels"soundtrack',
#   'dontdreamitsover',
#   'emotions',
#   'estanoche',
#   'gotherownfrom"charliesangels"soundtrack',
#   'grenade',
#   'higher',
#   'howilookonyoufrom"charliesangels"soundtrack',
#   'idontwanttobealoneforchristmas',
#   'ihavenothing',
#   'iwontsayiminlove',
#   'intoyouremix',
#   'introinterlude',
#   'knewbetterpartii',
#   'letitrain',
#   'lovethewayyoulie',
#   'monopoly',
#   'myheartbelongstodaddy',
#   'nobodyfrom"charliesangels"soundtrack',
#   'nobodydoesitbetter',
#   'onelasttimeattendsmoi',
#   'onlygirlintheworld',
#   'pinkchampagne',
#   'putyourheartsup',
#   'rainonme',
#   'reflection',
#   'ridiculous',
#   'santatellme',
#   'somewhereovertherainbow',
#   'stickaround',
#   'stillhurting',
#   'stuckwithu',
#   'suddenlyseymour',
#   'suitcase',
#   'thebeautywithinyou',
#   'theydontknowfrom"trolls"soundtrack',
#   'vienna',
#   'voodoolove',
#   'youremyonlyshawty',
#   'zerotoherofrom"welovedisney"compilation'],
#  'justinbieber': ['onetime',
#   'favoritegirl',
#   'downtoearth',
#   'bigger',
#   'onelesslonelygirl',
#   'firstdance',
#   'loveme',
#   'commondenominatoritunesbonustrack',
#   'onelesslonelygirlfrenchadaptation',
#   'baby',
#   'somebodytolove',
#   'stuckinthemoment',
#   'usmile',
#   'runawaylove',
#   'neverletyougo',
#   'overboard',
#   'eeniemeenie',
#   'up',
#   'thatshouldbeme',
#   'kissandtellitunesbonustrack',
#   'whereareyounowwalmartbonustrack',
#   'neversayneverthemesongfrom"thekaratekid"film',
#   'thatshouldbemeremix',
#   'somebodytoloveremix',
#   'upremix',
#   'overboardlivefeatmileycyrus',
#   'runawayloveremix',
#   'borntobesomebody',
#   'onlythingievergetforchristmas',
#   'mistletoe',
#   'thechristmassongchestnutsroastingonanopenfire',
#   'santaclausiscomingtotown',
#   'falala',
#   'alliwantforchristmasisyousuperfestive!',
#   'drummerboy',
#   'christmaseve',
#   'alliwantisyou',
#   'homethischristmas',
#   'silentnight',
#   'christmaslovedeluxeeditionbonustrack',
#   'falalaacapelladeluxeeditionbonustrack',
#   'praydeluxeeditionbonustrack',
#   'somedayatchristmasdeluxeeditionbonustrack',
#   'allaroundtheworld',
#   'boyfriend',
#   'aslongasyouloveme',
#   'takeyou',
#   'righthere',
#   'catchingfeelings',
#   'fall',
#   'dieinyourarms',
#   'thoughtofyou',
#   'beautyandabeat',
#   'onelove',
#   'bealright',
#   'believedeluxeeditionbonustrack',
#   'outoftowngirldeluxeeditionbonustrack',
#   'shedontlikethelightsdeluxeeditionbonustrack',
#   'mariadeluxeeditionbonustrack',
#   'heygirlticketmasterbonustrack',
#   'justlikethemjapanesebonustrack',
#   'lovemelikeyoudoitunesbonustrack',
#   'fairytaleswedishbonustrack',
#   'boyfriendacousticversion',
#   'aslongasyoulovemeacousticversion',
#   'beautyandabeatacousticversion',
#   'shedontlikethelightsacousticversion',
#   'takeyouacousticversion',
#   'bealrightacousticversion',
#   'allaroundtheworldacousticversion',
#   'yellowraincoat',
#   'iwould',
#   'nothinglikeusbonustrack',
#   'heartbreaker',
#   'allthatmatters',
#   'holdtight',
#   'recovery',
#   'badday',
#   'allbad',
#   'pyd',
#   'rollercoaster',
#   'changeme',
#   'confident',
#   'onelife',
#   'backpack',
#   'whatshatnin',
#   'swapitout',
#   'memphis',
#   'markmywords',
#   'illshowyou',
#   'whatdoyoumean',
#   'sorry',
#   'loveyourself',
#   'company',
#   'nopressure',
#   'nosense',
#   'thefeeling',
#   'lifeisworthliving',
#   'whereareünow',
#   'children',
#   'purpose',
#   'beenyoudeluxeeditionbonustrack',
#   'getusedtoitdeluxeeditionbonustrack',
#   'wearedeluxeeditionbonustrack',
#   'trustdeluxeeditionbonustrack',
#   'allinitdeluxeeditionbonustrack',
#   'whatdoyoumeanremixitunesbonustrack',
#   'hitthegroundjapaneseeditionbonustrack',
#   'themostjapaneseeditionbonustrack',
#   'hometomamajapaneseeditionbonustrack',
#   'allaroundme',
#   'habitual',
#   'comearoundme',
#   'intentions',
#   'yummy',
#   'available',
#   'forever',
#   'runningover',
#   'takeitoutonme',
#   'secondemotion',
#   'getme',
#   'eta',
#   'changes',
#   'confirmation',
#   'thatswhatloveis',
#   'atleastfornow',
#   'yummyremix',
#   '2much',
#   'deserveyou',
#   'asiam',
#   'offmyface',
#   'holy',
#   'unstable',
#   'mlkinterlude',
#   'dieforyou',
#   'holdon',
#   'somebody',
#   'ghost',
#   'peaches',
#   'loveyoudifferent',
#   'lovedbyyou',
#   'anyone',
#   'lonely',
#   'redeyebonustrack',
#   'haileybonustrack',
#   'angelsspeaktargetbonustrack',
#   'thereshegodeluxeeditionbonustrack',
#   'icantbemyselfdeluxeeditionbonustrack',
#   'lifetimedeluxeeditionbonustrack',
#   'wishyouwoulddeluxeeditionbonustrack',
#   'knownobetterdeluxeeditionbonustrack',
#   'namedeluxeeditionbonustrack',
#   'freedom',
#   'allshewrote',
#   'wereinthistogether',
#   'whereyougoifollow',
#   'wheredoifitin',
#   'afraidtosay',
#   '10000hours',
#   'aintafraid',
#   'allyours',
#   'alone',
#   'antidepressant',
#   'baby"myworldsacoustic"version',
#   'badguy',
#   'boyfriendremix',
#   'broken',
#   'californiacruisin',
#   'cantlivewithoutyou',
#   'choosin',
#   'coincidence',
#   'coldwater',
#   'comehometome',
#   'despacitoremix',
#   'dontgofar',
#   'doublenegative',
#   'drbieber',
#   'feelmylove',
#   'flatline',
#   'friends',
#   'friendsdvsnremix',
#   'future',
#   'happynewyear',
#   'hard2facereality',
#   'heartache',
#   'hotlineblingremix',
#   'howtoloveremix',
#   'idontcare',
#   'illbethere',
#   'intentionsacoustic',
#   'intertwine',
#   'itsworking',
#   'latingirl',
#   'lookingforyou',
#   'madlyinlovebiggerthanlife',
#   'makeyoubelieve',
#   'mamasboy',
#   'miamor',
#   'monster',
#   'moodremix',
#   'oldschoolflow',
#   'omahamall',
#   'onedanceremix',
#   'otisfreestyle',
#   'pickme',
#   'playtime',
#   'raisethebar',
#   'ride',
#   'rockinaroundthechristmastree',
#   'setaplaceatyourtable',
#   'slowup',
#   'sorrylatinoremix',
#   'speakingintongues',
#   'stress',
#   'strong',
#   'stuckwithu',
#   'swaggsmean',
#   'thatshouldbemeacoustic',
#   'theintro',
#   'thickorthin',
#   'thinkingaboutyou',
#   'trustissuesremix',
#   'trustme',
#   'turntoyou',
#   'uhoh',
#   'waitforaminute',
#   'wewerebornforthis',
#   'yeaya',
#   'youwantme',
#   'yummycountryremix'],
#  'katyperry': ['trustinme',
#   'piercing',
#   'searchme',
#   'lastcall',
#   'growingpains',
#   'myownmonster',
#   'spit',
#   'faithwontfail',
#   'naturally',
#   'whentheresnothingleft',
#   'box',
#   'diamonds',
#   'hookup',
#   'longshot',
#   'itsokaytobelieve',
#   'simple',
#   'takesonetoknowone',
#   'wishyoutheworst',
#   'weighmedown',
#   'oneoftheboys',
#   'ikissedagirl',
#   'wakingupinvegas',
#   'thinkingofyou',
#   'mannequin',
#   'ursogay',
#   'hotncold',
#   'ifyoucanaffordme',
#   'lost',
#   'selfinflicted',
#   'imstillbreathing',
#   'fingerprints',
#   'ithinkimreadyitunesbonustrack',
#   'acupofcoffeewalmartdigitaleditionbonustrack',
#   'teenagedream',
#   'lastfridaynighttgif',
#   'californiagurls',
#   'firework',
#   'peacock',
#   'circlethedrain',
#   'theonethatgotaway',
#   'et',
#   'whoamilivingfor',
#   'pearl',
#   'hummingbirdheartbeat',
#   'notlikethemovies',
#   'theonethatgotawayacousticthecompleteconfectionbonustrack',
#   'partofmethecompleteconfectionbonustrack',
#   'wideawakethecompleteconfectionbonustrack',
#   'dressinupthecompleteconfectionbonustrack',
#   'etthecompleteconfectionbonustrack',
#   'lastfridaynighttgifthecompleteconfectionbonustrack',
#   'tommiesunshinesmegasixsmashupthecompleteconfectionbonustrack',
#   'roar',
#   'legendarylovers',
#   'birthday',
#   'walkingonair',
#   'unconditionally',
#   'darkhorse',
#   'thisishowwedo',
#   'internationalsmile',
#   'ghost',
#   'loveme',
#   'thismoment',
#   'doublerainbow',
#   'bythegraceofgod',
#   'spiritualdeluxeeditionbonustrack',
#   'ittakestwodeluxeeditionbonustrack',
#   'chooseyourbattlesdeluxeeditionbonustrack',
#   'witness',
#   'heyheyhey',
#   'roulette',
#   'swishswish',
#   'déjàvu',
#   'power',
#   'mindmaze',
#   'missyoumore',
#   'chainedtotherhythm',
#   'tsunami',
#   'bonappetit',
#   'biggerthanme',
#   'saveasdraft',
#   'pendulum',
#   'intomeyousee',
#   'dancewiththedevildeluxeeditionbonustrack',
#   'actmyagedeluxeeditionbonustrack',
#   'neverreallyover',
#   'cryaboutitlater',
#   'tearyeyes',
#   'daisies',
#   'resilient',
#   'nottheendoftheworld',
#   'smile',
#   'champagneproblems',
#   'tucked',
#   'harleysinhawaii',
#   'onlylove',
#   'whatmakesawoman',
#   'messagefromkatyjapaneseeditionbonustrack',
#   'highonyoursupplyjapaneseeditionbonustrack',
#   'smalltalkjapaneseeditionbonustrack',
#   'neverwornwhitejapaneseeditionbonustrack',
#   'daisiesacousticjapaneseeditionbonustrack',
#   'daisiesoliverheldensremixjapaneseeditionbonustrack',
#   '365',
#   'blackandgold',
#   'bonappétitsoloversion',
#   'breakout',
#   'brickbybrick',
#   'broken',
#   'bullet',
#   'californiagurlsmusicvideoversion',
#   'californiagurlsnorapradioedit',
#   'chainedtotherhythmboatremix',
#   'chainedtotherhythmhotchipremix',
#   'concalmaremix',
#   'cozylittlechristmas',
#   'daisiescantcancelpride',
#   'damn',
#   'darkhorseelephanteremix',
#   'darkhorseremix',
#   'electricfeel',
#   'everydayisaholiday',
#   'girlnextdoor',
#   'hackensack',
#   'headoverheels',
#   'immortalflamefrom"finalfantasybraveexvius"soundtrack',
#   'inbetween',
#   'lookbutdonttouch',
#   'milkmilklemonade',
#   'nothinglikethefirsttime',
#   'partofmedemo',
#   'passenger',
#   'resilienttiëstoremix',
#   'rise2016summerolympicsanthem',
#   'speeddialin',
#   'spendthenight',
#   'swishswishblonderemix',
#   'swishswishvalentinokhanremix',
#   'tshirt',
#   'thatsmorelikeit',
#   'thebetterhalfofme',
#   'thedriveway',
#   'theonethatgotawayremix',
#   'timesup',
#   'useyourlove',
#   'wavingthroughawindow',
#   'whateveryousay'],
#  'jackson': ['aintnosunshine',
#   'iwannabewhereyouare',
#   'girldonttakeyourlovefromme',
#   'inoursmallway',
#   'gottobethere',
#   'rockinrobin',
#   'wingsofmylove',
#   'mariayouweretheonlyone',
#   'loveishereandnowyouregone',
#   'youvegotafriend',
#   'ben',
#   'thegreatestshowonearth',
#   'peoplemaketheworldgoround',
#   'wevegotagoodthinggoing',
#   'everybodyssomebodysfool',
#   'mygirl',
#   'whatgoesaroundcomesaround',
#   'shoobedoobedoodaday',
#   'youcancryonmyshoulder',
#   'withachildsheart',
#   'upagain',
#   'allthethingsyouare',
#   'happy',
#   'tooyoung',
#   'dogginaround',
#   'johnnyraven',
#   'euphoria',
#   'morningglow',
#   'musicandme',
#   'werealmostthere',
#   'takemeback',
#   'onedayinyourlife',
#   'cinderellastayawhile',
#   'wevegotforever',
#   'justalittlebitofyou',
#   'youarethere',
#   'dapperdanfreestyle',
#   'dearmichael',
#   'illcomehometoyou',
#   'dontstoptilyougetenough',
#   'rockwithyou',
#   'workingdayandnight',
#   'getonthefloor',
#   'offthewall',
#   'girlfriend',
#   'shesoutofmylife',
#   'icanthelpit',
#   'itsthefallinginlove',
#   'burnthediscoout',
#   'wannabestartinsomethin',
#   'babybemine',
#   'thegirlismine',
#   'thriller',
#   'beatit',
#   'billiejean',
#   'humannature',
#   'pytprettyyoungthing',
#   'theladyinmylife',
#   'carousel',
#   'dontletitgetyoudown',
#   'youvereallygotaholdonme',
#   'melodie',
#   'touchtheoneyoulove',
#   'girlyouresotogether',
#   'farewellmysummerlove',
#   'callonme',
#   'hereiamcomeandtakeme',
#   'tomakemyfatherproud',
#   'bad',
#   'thewayyoumakemefeel',
#   'speeddemon',
#   'liberiangirl',
#   'justgoodfriends',
#   'anotherpartofme',
#   'maninthemirror',
#   'ijustcantstoplovingyou',
#   'dirtydiana',
#   'smoothcriminal',
#   'leavemealone',
#   'streetwalker2001specialedition',
#   'flyaway2001specialedition',
#   'jam',
#   'whyyouwannatriponme',
#   'inthecloset',
#   'shedrivesmewild',
#   'rememberthetime',
#   'cantlethergetaway',
#   'healtheworld',
#   'blackorwhite',
#   'whoisit',
#   'giveintome',
#   'willyoubethere',
#   'keepthefaith',
#   'gonetoosoon',
#   'dangerous',
#   'scream',
#   'theydontcareaboutus',
#   'strangerinmoscow',
#   'thistimearound',
#   'earthsong',
#   'ds',
#   'money',
#   'cometogether',
#   'youarenotalone',
#   'childhood',
#   'tabloidjunkie',
#   '2bad',
#   'history',
#   'littlesusie',
#   'smile',
#   'bloodonthedancefloor',
#   'morphine',
#   'superflysister',
#   'ghosts',
#   'isitscary',
#   'unbreakable',
#   'heartbreaker',
#   'invincible',
#   'breakofdawn',
#   'heavencanwait',
#   'yourockmyworld',
#   'butterflies',
#   'speechless',
#   '2000watts',
#   'youaremylife',
#   'dontwalkaway',
#   'privacy',
#   'cry',
#   'thelostchildren',
#   'whateverhappens',
#   'threatened',
#   'beautifulgirl',
#   'cheater',
#   'fallagain',
#   'intheback',
#   'monkeybusiness',
#   'scaredofthemoon',
#   'someoneinthedark',
#   'sunsetdriver',
#   'thewayyouloveme',
#   'weareheretochangetheworld',
#   'wevehadenough',
#   'holdmyhand',
#   'hollywoodtonight',
#   'keepyourheadup',
#   'ilikethewayyouloveme',
#   'monster',
#   'bestofjoy',
#   'breakingnews',
#   'icantmakeitanotherday',
#   'behindthemask',
#   'muchtoosoon',
#   'workindayandnightimmortalversion',
#   'theimmortalintroimmortalversion',
#   'childhoodimmortalversion',
#   'wannabestartinsomethinimmortalversion',
#   'shakeyourbodydowntothegroundimmortalversion',
#   'dancingmachineblameitontheboogieimmortalversion',
#   'benimmortalversion',
#   'thisplacehotelimmortalversion',
#   'smoothcriminalimmortalversion',
#   'dangerousimmortalversion',
#   'themimesegmentilikethewayyoulovemespeeddemonanotherpartofmeimmortalversion',
#   'thejackson5medleyiwantyoubackabctheloveyousaveimmortalversion',
#   'speechlesshumannatureimmortalversion',
#   'isitscarythreatenedimmortalversion',
#   'thrillerimmortalversion',
#   'youarenotaloneijustcantstoplovingyouimmortalversion',
#   'beatitstateofshockimmortalversion',
#   'jamimmortalversion',
#   'planetearthearthsongimmortalversion',
#   'screamlittlesusieimmortalversion',
#   'gonetoosoonimmortalversion',
#   'theydontcareaboutusimmortalversion',
#   'willyoubethereimmortalversion',
#   'illbethereimmortalversion',
#   'immortalmegamixcanyoufeelitdontstoptilyougetenoughbilliejeanblackorwhiteimmortalversion',
#   'maninthemirrorimmortalversion',
#   'rememberthetimebadimmortalversion',
#   'dontbemessinround',
#   'imsoblue',
#   'songgrooveakaabortionpapers',
#   'free',
#   'priceoffame',
#   'alcapone',
#   'todomiamorerestú',
#   'jeneveuxpaslafindenous',
#   'badafrojackremixdjbuddhaedit',
#   'speeddemonneroremix',
#   'loveneverfeltsogood',
#   'chicago',
#   'lovingyou',
#   'aplacewithnoname',
#   'slavetotherhythm',
#   'doyouknowwhereyourchildrenare',
#   'bluegangsta',
#   'xscape',
#   'loveneverfeltsogoodwithjustintimberlake',
#   'allineed',
#   'allinyourname',
#   'allright',
#   'blackwidow',
#   'bloodonthedancefloorxdangerousthewhitepandamashup',
#   'burntonight',
#   'butterfliesremix',
#   'canyoufeelitfrom"theessentialmichaeljackson"compilation',
#   'cantgetouttatherainfrom"billiejean"single',
#   'cantgetyourweightoffofme',
#   'daysingloucestershire',
#   'diamondsareinvincible',
#   'elizabethiloveyou',
#   'fallinlove',
#   'foralltime',
#   'gotthehots',
#   'hotstreet',
#   'iamaloser',
#   'ifyoudontloveme',
#   'letmeletgo',
#   'mindisthemagic',
#   'niteline',
#   'ontheline',
#   'onemorechance',
#   'peopleoftheworld',
#   'pepsinewgeneration',
#   'ready2win',
#   'seeingvoices',
#   'seriouseffect',
#   'shakeyourbodydowntothegroundfrom"theessentialmichaeljackson"compilation',
#   'shegotit',
#   'shewaslovinme',
#   'shout',
#   'slapstick',
#   'slavetotherhythmfeatjustinbieber',
#   'soldierboy',
#   'someoneputyourhandout',
#   'stay',
#   'thegirlismine2008',
#   'theremustbemoretolifethanthis',
#   'thisisit',
#   'todoparatispanishversionof"whatmorecanigive"',
#   'trouble',
#   'wannabestartinsomethin2008',
#   'water',
#   'wearetheworld',
#   'whatmorecanigive',
#   'workthatbody',
#   'youcantwin',
#   'youreallygotaholdonme',
#   'youwerethere'],
#  'billieeilish': ['copycat',
#   'idontwannabeyouanymore',
#   'myboy',
#   'watch',
#   'partyfavor',
#   'bellyache',
#   'oceaneyes',
#   'hostage',
#   'andburn',
#   '!!!!!!!',
#   'badguy',
#   'xanny',
#   'youshouldseemeinacrown',
#   'allthegoodgirlsgotohell',
#   'wishyouweregay',
#   'whenthepartysover',
#   '8',
#   'mystrangeaddiction',
#   'buryafriend',
#   'ilomilo',
#   'listenbeforeigo',
#   'iloveyou',
#   'goodbye',
#   'comeoutandplayjapanesebonustrack',
#   'wheniwasolderjapanesebonustrack',
#   '61818',
#   'anotherstupidsong',
#   'bad',
#   'badguywithjustinbieber',
#   'bitchesbrokenhearts',
#   'boredfrom"13reasonswhy"soundtrack',
#   'callmeback',
#   'everythingiwanted',
#   'fingerscrossed',
#   'limbo',
#   'lovasaolvidar',
#   'lovelyfrom"13reasonswhyseason2"soundtrack',
#   'myfuture',
#   'notimetodiefrom"jamesbondnotimetodie"soundtrack',
#   'oceaneyesastronomyyedit',
#   'oceaneyesblackbearremix',
#   'seethrough',
#   'shesbroken',
#   'sixfeetunder',
#   'theendoftheworld',
#   'thehill',
#   'thereforeiam',
#   'trueblue',
#   'youdontgetmehighanymore'],
#  'madonna': ['luckystar',
#   'borderline',
#   'burningup',
#   'iknowit',
#   'holiday',
#   'thinkofme',
#   'physicalattraction',
#   'everybody',
#   'materialgirl',
#   'angel',
#   'likeavirgin',
#   'overandover',
#   'lovedontlivehereanymore',
#   'dressyouup',
#   'shoobeedoo',
#   'pretender',
#   'stay',
#   'papadontpreach',
#   'openyourheart',
#   'whiteheat',
#   'livetotell',
#   'wherestheparty',
#   'trueblue',
#   'laislabonita',
#   'jimmyjimmy',
#   'lovemakestheworldgoround',
#   'whosthatgirl',
#   'causingacommotion',
#   'thelookoflove',
#   'cantstop',
#   'likeaprayer',
#   'expressyourself',
#   'lovesong',
#   'tilldeathdouspart',
#   'promisetotry',
#   'cherish',
#   'dearjessie',
#   'ohfather',
#   'keepittogether',
#   'spanisheyes',
#   'actofcontrition',
#   'hesaman',
#   'soonerorlater',
#   'hankypanky',
#   'imgoingbananas',
#   'crybaby',
#   'somethingtoremember',
#   'backinbusiness',
#   'more',
#   'whatcanyoulose',
#   'nowimfollowingyouparti',
#   'nowimfollowingyoupartii',
#   'vogue',
#   'erotica',
#   'fever',
#   'byebyebaby',
#   'deeperanddeeper',
#   'wherelifebegins',
#   'badgirl',
#   'waiting',
#   'thiefofhearts',
#   'words',
#   'rain',
#   'whysitsohard',
#   'inthislife',
#   'didyoudoit',
#   'secretgarden',
#   'survival',
#   'secret',
#   'idratherbeyourlover',
#   'dontstop',
#   'insideofme',
#   'humannature',
#   'forbiddenlove',
#   'lovetriedtowelcomeme',
#   'sanctuary',
#   'bedtimestory',
#   'takeabow',
#   'iwantyou',
#   'illremember',
#   'youllsee',
#   'thisusedtobemyplayground',
#   'onemorechance',
#   'acinemainbuenosaires26july1952',
#   'requiemforevita',
#   'ohwhatacircus',
#   'onthisnightofathousandstars',
#   'evaandmagaldievabewareofthecity',
#   'buenosaires',
#   'anothersuitcaseinanotherhall',
#   'goodnightandthankyou',
#   'theladysgotpotential',
#   'charityconcerttheartofthepossible',
#   'idbesurprisinglygoodforyou',
#   'helloandgoodbye',
#   'peronslatestflame',
#   'anewargentina',
#   'onthebalconyofthecasarosada1',
#   'dontcryformeargentina',
#   'onthebalconyofthecasarosada2',
#   'highflyingadored',
#   'rainbowhigh',
#   'rainbowtour',
#   'theactresshasntlearnedthelinesyoudliketohear',
#   'andthemoneykeptrollinginandout',
#   'partidofeminista',
#   'sheisadiamond',
#   'santaevita',
#   'waltzforevaandche',
#   'yourlittlebodysslowlybreakingdown',
#   'youmustloveme',
#   'evasfinalbroadcast',
#   'latinchant',
#   'lament',
#   'laughtokeepfromcrying',
#   'crimesofpassion',
#   'aintnobigdeal97edit',
#   'everybody97and81',
#   'aintnobigdeal81and97extended',
#   'stay81',
#   'dontyouknow',
#   'drownedworldsubstituteforlove',
#   'swim',
#   'rayoflight',
#   'candyperfumegirl',
#   'skin',
#   'nothingreallymatters',
#   'skyfitsheaven',
#   'shantiashtangi',
#   'frozen',
#   'thepowerofgoodbye',
#   'tohaveandnottohold',
#   'littlestar',
#   'mergirl',
#   'hastobe',
#   'music',
#   'impressiveinstant',
#   'runawaylover',
#   'ideserveit',
#   'amazing',
#   'nobodysperfect',
#   'donttellme',
#   'whatitfeelslikeforagirl',
#   'paradisenotforme',
#   'gone',
#   'cyberraga',
#   'americanlife',
#   'hollywood',
#   'imsostupid',
#   'loveprofusion',
#   'nobodyknowsme',
#   'nothingfails',
#   'intervention',
#   'xstaticprocess',
#   'motherandfather',
#   'dieanotherday',
#   'easyride',
#   'nothingfailsnevinsmix',
#   'loveprofusionheadcleanerrockmix',
#   'nobodyknowsmemountsimsoldschoolmix',
#   'americanlifeheadcleanerrockmix',
#   'likeavirginhollywoodmedley2003mtvvmaperformance',
#   'intothehollywoodgroovethepassengerzmix',
#   'yourhonesty',
#   'hungup',
#   'gettogether',
#   'sorry',
#   'futurelovers',
#   'ilovenewyork',
#   'letitwillbe',
#   'jump',
#   'howhigh',
#   'isaac',
#   'push',
#   'likeitornot',
#   'fightingspiritcddeluxeeditionbonustrack',
#   'candyshop',
#   '4minutes',
#   'giveit2me',
#   'heartbeat',
#   'milesaway',
#   'shesnotme',
#   'incredible',
#   'beatgoeson',
#   'dance2night',
#   'spanishlesson',
#   'devilwouldntrecognizeyou',
#   'voices',
#   'ringmybellitunesbonustrack',
#   'girlgonewild',
#   'gangbang',
#   'imaddicted',
#   'turnuptheradio',
#   'givemeallyourluvin',
#   'somegirls',
#   'superstar',
#   'idontgivea',
#   'imasinner',
#   'lovespentdeluxeeditionbonustrack',
#   'masterpiece',
#   'fallingfree',
#   'beautifulkillerdeluxeeditionbonustrack',
#   'ifuckedupdeluxeeditionbonustrack',
#   'bdaysongdeluxeeditionbonustrack',
#   'bestfrienddeluxeeditionbonustrack',
#   'givemeallyourluvinpartyrockremixdeluxeeditionbonustrack',
#   'livingforlove',
#   'devilpray',
#   'ghosttown',
#   'unapologeticbitch',
#   'illuminati',
#   'bitchimmadonna',
#   'holdtight',
#   'joanofarc',
#   'iconic',
#   'heartbreakcity',
#   'bodyshop',
#   'holywater',
#   'insideout',
#   'washalloverme',
#   'bestnightdeluxeeditionbonustrack',
#   'venivedivicideluxeeditionbonustrack',
#   'sexdeluxeeditionbonustrack',
#   'messiahdeluxeeditionbonustrack',
#   'rebelheartdeluxeeditionbonustrack',
#   'beautifulscarssuperdeluxeeditionbonustrack',
#   'borrowedtimesuperdeluxeeditionbonustrack',
#   'addicted',
#   'graffitiheartsuperdeluxeeditionbonustrack',
#   'autotunebabymediamarktbonustrack',
#   'medellín',
#   'darkballet',
#   'godcontrol',
#   'future',
#   'batuka',
#   'killerswhoarepartying',
#   'crave',
#   'crazy',
#   'comealive',
#   'extremeoccidentdeluxeeditionbonustrack',
#   'fazgostoso',
#   'bitchimloca',
#   'idontsearchifind',
#   'lookingformercydeluxeeditionbonustrack',
#   'irise',
#   'funanaboxsetbonustrack',
#   'backthatuptothebeatboxsetbonustrack',
#   'ciaobellaboxsetbonustrack',
#   'acrossthesky',
#   'addictedtheonethatgotaway',
#   'americanlifeamericandreamremix',
#   'americanpie',
#   'angelswithdirtyfaces',
#   'animal',
#   'arioso',
#   'becarefulwithmyheart',
#   'beautifulstrangerfrom"austinpowersthespywhoshaggedme"soundtrack',
#   'brokenimsorry',
#   'celebrationfrom"celebration"greatesthitsalbum',
#   'celebrationremix',
#   'crazyforyou',
#   'dontcryformeargentinamiamispanglishmix',
#   'erotic',
#   'freedom',
#   'gambler',
#   'getup',
#   'ghv2megamix',
#   'goodbyetoinnocence',
#   'guiltybyassociation',
#   'heyyou',
#   'history',
#   'icantforget',
#   'ifyouforgetme',
#   'intothegroovefrom"celebration"greatesthitsalbum',
#   'itssocoolfrom"celebration"greatesthitsalbum',
#   'justadream',
#   'justifymylovefrom"theimmaculatecollection"greatesthitsalbum',
#   'justifymylovethebeastwithinmix',
#   'keepthetrance',
#   'latte',
#   'letdownyourguardroughmixedit',
#   'liesinyoureyes',
#   'likeaflower',
#   'likeaprayerfrom"hopeforhaitinow"compilation',
#   'littleboylost',
#   'loveontherun',
#   'meagainstthemusic',
#   'missyou',
#   'neverletyougo',
#   'neverloveastranger',
#   'nosubstituteforlove',
#   'nothinglastsforever',
#   'ontheground',
#   'queen',
#   'rescuemefrom"theimmaculatecollection"greatesthitsalbum',
#   'revolution',
#   'revolverfrom"celebration"greatesthitsalbum',
#   'santababy',
#   'scheherazade',
#   'settheright',
#   'shinealight',
#   'sidewalktalkextendeddancemix',
#   'spotlightfrom"youcandance"album',
#   'superpop',
#   'supernaturaloriginalarmshousemix',
#   'timestoodstillfrom"thenextbestthing"soundtrack',
#   'triggering',
#   'verasyoullsee',
#   'youthrillme'],
#  'selenagomez': ['birthday',
#   'slowdown',
#   'starsdance',
#   'likeachampion',
#   'comeandgetit',
#   'forgetforever',
#   'savetheday',
#   'beat',
#   'writeyourname',
#   'undercover',
#   'lovewillremember',
#   'nobodydoesitlikeyouitunesbonustrack',
#   'musicfeelsbetteritunesbonustrack',
#   'loverinmetargetbonustrack',
#   'ilikeitthatwaytargetbonustrack',
#   'theheartwantswhatitwants',
#   'loveyoulikealovesong',
#   'tellmesomethingidontknow',
#   'whosays',
#   'mydilemma20',
#   'roundandround',
#   'ayearwithoutrain',
#   'naturally',
#   'más',
#   'bidibidibombom',
#   'fallingdown',
#   'doit',
#   'revival',
#   'killemwithkindness',
#   'handstomyself',
#   'sameoldlove',
#   'sober',
#   'goodforyou',
#   'camouflage',
#   'meandtherhythm',
#   'survivors',
#   'bodyheat',
#   'rise',
#   'meandmygirlsdeluxeeditionbonustrack',
#   'nobodydeluxeeditionbonustrack',
#   'perfectdeluxeeditionbonustrack',
#   'outtamyhandslocodeluxeeditionbonustrack',
#   'colognedeluxeeditionbonustrack',
#   'rare',
#   'danceagain',
#   'lookathernow',
#   'loseyoutoloveme',
#   'ring',
#   'vulnerable',
#   'peopleyouknow',
#   'letmegetme',
#   'crowdedroom',
#   'kindacrazy',
#   'fun',
#   'cutyouoff',
#   'asweeterplace',
#   'badliarbonustrack',
#   'fetishbonustrack',
#   'itaintmebonustrack',
#   'backtoyoubonustrack',
#   'wolvesbonustrack',
#   'boyfrienddeluxeeditionbonustrack',
#   'souvenirdeluxeeditionbonustrack',
#   'shedeluxeeditionbonustrack',
#   'feelmedeluxeeditionbonustrack',
#   'deunavez',
#   'buscandoamor',
#   'bailaconmigo',
#   'dámeloto',
#   'vicio',
#   'adiós',
#   'selfishlove',
#   'bangadrumfrom"anothercinderellastory"soundtrack',
#   'brainzappedfrom"brainzapped"soundtrack',
#   'congratulationstome',
#   'cruelladevilfrom"disneymania6"',
#   'disappearfrom"wizardsofwaverlyplace"soundtrack',
#   'everythingisnotwhatitseemsfrom"wizardsofwaverlyplace"soundtrack',
#   'fetishgalantisremix',
#   'flytoyourheartfrom"tinkerbell"soundtrack',
#   'holdonfrom"rudderless"soundtrack',
#   'icantgetenough',
#   'iwantyoutoknow',
#   'icecream',
#   'magicfrom"wizardsofwaverlyplace"soundtrack',
#   'magicalfrom"wizardsofwaverlyplace"soundtrack',
#   'makeithappen',
#   'newclassicfrom"anothercinderellastory"soundtrack',
#   'oneandthesamefrom"disneychannelplaylist"',
#   'onlyyoufrom"13reasonswhy"soundtrack',
#   'pastlifeduet',
#   'perfectly',
#   'sadserenade',
#   'sameoldloveremix',
#   'senditon',
#   'shakeitup',
#   'stained',
#   'trustinmefrom"disneymania7"',
#   'unfamiliar'],
#  'rihanna': ['pondereplay',
#   'hereigoagain',
#   'ifitslovinthatyouwant',
#   'youdontlovemenonono',
#   'thatlalala',
#   'thelasttime',
#   'willingtowait',
#   'musicofthesun',
#   'letme',
#   'rush',
#   'theresathuginmylife',
#   'nowiknow',
#   'pondereplayremix',
#   'sos',
#   'kissesdontlie',
#   'unfaithful',
#   'weride',
#   'demhaters',
#   'finalgoodbye',
#   'breakitoff',
#   'crazylittlethingcalledlove',
#   'selfishgirl',
#   'psimstillnotoveryou',
#   'agirllikeme',
#   'amillionmilesaway',
#   'ifitslovinthatyouwantpt2',
#   'whoyagonnaruntodeluxeeditionbonustrack',
#   'couldabeentheonedeluxeeditionbonustrack',
#   'shouldideluxeeditionbonustrack',
#   'hypnotizeddeluxeeditionbonustrack',
#   'umbrella',
#   'pushuponme',
#   'dontstopthemusic',
#   'breakindishes',
#   'shutupanddrive',
#   'hatethatiloveyou',
#   'sayit',
#   'sellmecandy',
#   'lemmegetthat',
#   'rehab',
#   'questionexisting',
#   'goodgirlgonebad',
#   'cryjapanesebonustrack',
#   'hauntedjapanesebonustrack',
#   'disturbiagoodgirlgonebadreloaded',
#   'takeabowgoodgirlgonebadreloaded',
#   'ifineverseeyourfaceagaingoodgirlgonebadreloaded',
#   'madhouse',
#   'waityourturn',
#   'hard',
#   'stupidinlove',
#   'rockstar101',
#   'russianroulette',
#   'firebomb',
#   'rudeboy',
#   'photographs',
#   'g4l',
#   'teamo',
#   'coldcaselove',
#   'thelastsong',
#   'holeinmyheadnokiacomeswithmusicbonustrack',
#   'sandm',
#   'whatsmyname',
#   'cheersdrinktothat',
#   'fading',
#   'onlygirlintheworld',
#   'californiakingbed',
#   'mandown',
#   'rainingmen',
#   'complicated',
#   'skin',
#   'lovethewayyouliepartii',
#   'youdaone',
#   'wherehaveyoubeen',
#   'wefoundlove',
#   'talkthattalk',
#   'cockinessloveit',
#   'birthdaycake',
#   'weallwantlove',
#   'drunkonlove',
#   'rocmeout',
#   'watchnlearn',
#   'farewell',
#   'redlipstickdeluxeeditionbonustrack',
#   'doyathangdeluxeeditionbonustrack',
#   'foolinlovedeluxeeditionbonustrack',
#   'wefoundloveextendedmixdeluxeeditionbonustrack',
#   'phreshouttherunway',
#   'diamonds',
#   'numb',
#   'pouritup',
#   'loveeeeeeesong',
#   'jump',
#   'rightnow',
#   'whatnow',
#   'stay',
#   'nobodysbusiness',
#   'lovewithouttragedymothermary',
#   'getitoverwith',
#   'noloveallowed',
#   'lostinparadise',
#   'halfofmedeluxeeditionbonustrack',
#   'diamondsdaveaudé100extendeddeluxeeditionbonustrack',
#   'diamondsgregorsaltodowntemporemixdeluxeeditionbonustrack',
#   'towardsthesun',
#   'asrealasyouandme',
# ...
#   'tough',
#   'grace',
#   'someoneyouloved',
#   'somethingborroweddemo',
#   'holdmewhileyouwait',
#   'maybe',
#   'forever',
#   'one',
#   'dontgetmewrong',
#   'hollywood',
#   'headspace',
#   'beforeyougoextendededitionbonustrack',
#   'leavingmylovebehindextendededitionbonustrack',
#   'letitrollextendededitionbonustrack',
#   '2002',
#   'athousandmiles',
#   'bamboo',
#   'daysgonequietfrom"daysgone"soundtrack',
#   'fallingtopieces',
#   'figureitout',
#   'halftheworldaway',
#   'issues',
#   'lastinglover',
#   'rush',
#   'shallow',
#   'theclimb',
#   'whenthepartysover',
#   'yesterday'],
#  'dnce': ['cakebytheocean',
#   'paymyrent',
#   'toothbrush',
#   'jinx',
#   'dnce',
#   'bodymoves',
#   'doctoryou',
#   'blown',
#   'goodday',
#   'almost',
#   'naked',
#   'truthfully',
#   'bemean',
#   'zoom',
#   'unsweet',
#   'tvinthemorning',
#   'stillgood',
#   'losemycool',
#   'manonfire',
#   'borntohandjivefrom"greaselive!"soundtrack',
#   'canyoufeelitfrom"mylittleponythemovie"soundtrack',
#   'christmaswithoutyou',
#   'dance',
#   'foreverfrom"thelegobatmanmovie"soundtrack',
#   'kissingstrangers',
#   'kissingstrangersremix',
#   'maybebabyfrom"greaselive!"soundtrack',
#   'whatslovegottodowithitfrom"thetimeisnow!"compilation'],
#  'lukasgraham': ['ordinarythings',
#   'niceguy',
#   'drunkinthemorning',
#   'whenyourewithmeinterlude',
#   'redwine',
#   'apologize',
#   'daddynowthatyouregoneaintnolove',
#   'criminalmind',
#   'betterthanyourselfcriminalmindpt2',
#   'donthurtmethisway',
#   'movingalone',
#   'oohhhinterlude',
#   'neverletmedown',
#   'beforethemorningsun',
#   '7years',
#   'taketheworldbystorm',
#   'mamasaid',
#   'happyhome',
#   'hayo',
#   'wheniwokeupinterlude',
#   'dontyouworryboutme',
#   'whathappenedtoperfect',
#   'playtime',
#   'stripnomore',
#   'yourenotthere',
#   'funeral',
#   'notadamnthingchanged',
#   'lullaby',
#   'yourenottheonlyoneredemptionsong',
#   'lovesomeone',
#   'promise',
#   'stickaround',
#   'unhappy',
#   'everythingthatisntme',
#   'holdmyhand',
#   'sayyeschurchballad',
#   'hereforchristmas',
#   'lie',
#   'lovesongs',
#   'offtoseetheworldfrom"mylittleponythemovie"soundtrack',
#   'sad!',
#   'scars',
#   'sharethatlove',
#   'whereimfrom'],
#  'tovelo': ['loveballad',
#   'notondrugs',
#   'paradise',
#   'over',
#   'habits',
#   'outofmind',
#   'stayhighhabitsremix',
#   'thesexinterlude',
#   'mygun',
#   'likeemyoung',
#   'talkingbody',
#   'timebomb',
#   'theloveinterlude',
#   'moments',
#   'thewaythatiam',
#   'gotlove',
#   'thepaininterlude',
#   'thousandmiles',
#   'thistimearound',
#   'runonlove',
#   'stayhighhabitsremixbonustrack',
#   'loveballadbonustrack',
#   'cravebonustrack',
#   'notmadeforthisworldbonustrack',
#   'influence',
#   'ladywood',
#   'truedisaster',
#   'coolgirl',
#   'vibes',
#   'firefade',
#   'donttalkaboutit',
#   'imaginaryfriend',
#   'keepitsimple',
#   'flashes',
#   'wtfloveis',
#   'lightbeamschapteriii',
#   'discotits',
#   'shedontknowbutsheknows',
#   'shiveringgold',
#   'dontaskdonttell',
#   'stranger',
#   'bitches',
#   'romantics',
#   'cycles',
#   'struggle',
#   '9thofoctober',
#   'baddays',
#   'heyyougotdrugs',
#   'grittyprettyintro',
#   'gladhesgone',
#   'badastheboys',
#   'sweettalkmyheart',
#   'stayover',
#   'areugonnatellher',
#   'jacques',
#   'mateo',
#   'comeundone',
#   'equallylost',
#   'reallydontlikeu',
#   'shifted',
#   'mistaken',
#   'anywhereugo',
#   'sadderbaddercoolerpawprintseditionbonustrack',
#   'imcomingpawprintseditionbonustrack',
#   'passionandpaintastethesamewhenimweakpawprintseditionbonustrack',
#   'bikiniporn',
#   'bitchesremix',
#   'buzzbuzzhophopfrom"athomewiththekids"compilation',
#   'callingonme',
#   'diva',
#   'evilspawn',
#   'goodguys',
#   'howdyoudoit',
#   'influencetm88taylorgangremix',
#   'jealousy',
#   'liesinthedarkfrom"fiftyshadesdarker"soundtrack',
#   'lifeitself',
#   'passionandpaintastesthesamewhenimweak',
#   'perfectloop',
#   'scarsfrom"thedivergentseriesallegiant"soundtrack',
#   'screammynamefrom"thehungergamesmockingjaypart1"soundtrack',
#   'whatiwantforthenightbitches',
#   'worstbehavior'],
#  'jamesarthur': ['bumblebee',
#   'cheapdreamrichdaddys',
#   'classic',
#   'holdon',
#   'releasethefreaktouchme',
#   'always',
#   'brokenhearted',
#   'carryus',
#   'confessions',
#   'ibelieve',
#   'nowayout',
#   'prettygirls',
#   'aintnothintoit',
#   'icantbeyoureverything',
#   'echoes',
#   'iunproudlypresent',
#   'yourenobodytilsomebodylovesyou',
#   'getdown',
#   'newtattoo',
#   'impossible',
#   'liedown',
#   'recovery',
#   'roses',
#   'supposed',
#   'suicide',
#   'isthislove',
#   'certainthings',
#   'smokeclouds',
#   'flyin',
#   'emergencydeluxeeditionbonustrack',
#   'tilikum',
#   'notguilty',
#   'wheremyangelsdarenottread',
#   'followtheleader',
#   'hype',
#   'thesummer',
#   'handtomouth',
#   'cigarandcongac',
#   'livelikeaqueen',
#   'worldtitle',
#   'whichclimbseasiest',
#   'turntheworldaround',
#   'backfromtheedge',
#   'sayyouwontletgo',
#   'prisoner',
#   'canibehim',
#   'iam',
#   'trainwreck',
#   'safeinside',
#   'sober',
#   'phoenix',
#   'letmelovethelonely',
#   'sermon',
#   'rememberwhoiwas',
#   'finally',
#   'thetruth',
#   'skeletons',
#   'ifonly',
#   'cominghomeforsummer',
#   'you',
#   'finallyfeelgood',
#   'marineparade2013',
#   'ifwecangetthroughthiswecangetthroughanything',
#   'carsoutside',
#   'quitemisshome',
#   'treehouse',
#   'sadeyes',
#   'unconditionally',
#   'homicidelove',
#   'breathe',
#   'maybe',
#   'fall',
#   'fallinglikethestars',
#   'emptyspace',
#   'naked',
#   'frommetoyouihateeverybody',
#   'alright',
#   'atmyweakest',
#   'beatthebullies',
#   'dufflebag',
#   'emotionalterrorist',
#   'fade',
#   'faded',
#   'fromthegravefrom"forthethrone"compilation',
#   'glorious',
#   'heroes',
#   'hurts',
#   'ineedafriend',
#   'illreachyou',
#   'imaliar',
#   'ifyouletme',
#   'ithurts',
#   'itsnotover',
#   'lasttime',
#   'lastinglover',
#   'letmewinit',
#   'longlivetheking',
#   'medicine',
#   'nobody',
#   'rewritethestarsfrom"thegreatestshowmanreimagined"compilation',
#   'silentnightvevoliveacoustic*',
#   'stopaskingmetocomeback',
#   'whenyourelosingsleepinaberdeen',
#   'youdeservebetter'],
#  'banks': ['alibi',
#   'goddess',
#   'waitinggame',
#   'brain',
#   'thisiswhatitfeelslike',
#   'youshouldknowwhereimcomingfrom',
#   'stick',
#   'fuckemonlyweknow',
#   'drowning',
#   'begginforthread',
#   'change',
#   'someonenew',
#   'warmwater',
#   'underthetable',
#   'andidroveyoucrazyitunesbonustrack',
#   'falloveritunesbonustrack',
#   'beforeievermetyouitunesbonustrack',
#   'bedroomwallitunesbonustrack',
#   'geminifeed',
#   'fuckwithmyself',
#   'lovesick',
#   'mindgames',
#   'trainwreck',
#   'thisisnotaboutus',
#   'weakergirl',
#   'motherearth',
#   'judas',
#   'haunt',
#   'poltergeist',
#   'tothehilt',
#   '27hours',
#   'tillnow',
#   'gimme',
#   'contaminated',
#   'stroke',
#   'godless',
#   'sawzall',
#   'lookwhatyouredoingtome',
#   'hawaiianmazes',
#   'alaska',
#   'propaganda',
#   'thefall',
#   'ifweweremadeofwater',
#   'whataboutlove',
#   'areyouthatsomebody',
#   'better',
#   'crowdedplaces',
#   'drowninglovethybrotherremix',
#   'inyoureyes',
#   'underdog',
#   'whatyouneed'],
#  'jessiereyez': ['fuckit',
#   'shutterisland',
#   'blueribbon',
#   'figures',
#   'gatekeeper',
#   'colombiankingandqueen',
#   'greatone',
#   'saintnobody',
#   'applejuice',
#   'sola',
#   'fuckbeingfriends',
#   'dearyessie',
#   'imported',
#   'bodycountremix',
#   'doyouloveher',
#   'deafwhoareyou',
#   'intruders',
#   'coffin',
#   'ankles',
#   'lamemoria',
#   'sameside',
#   'roof',
#   'dope',
#   'killus',
#   'loveinthedark',
#   'ido',
#   'sugaratnighttargetbonustrack',
#   'noonesintheroomtargetbonustrack',
#   'farawaytargetbonustrack',
#   'farawayiideluxeeditionbonustrack',
#   'anklesremixdeluxeeditionbonustrack',
#   'worthsavingdeluxeeditionbonustrack',
#   'beforelovecametokillusbonustrack',
#   'bodycount',
#   'conelviento',
#   'cottoncandy',
#   'crazy',
#   'feelittoo',
#   'feelslikehome',
#   'figuresareprise',
#   'headlines',
#   'healing',
#   'importedspanglishversion',
#   'lointentétodo',
#   'nosweat',
#   'oceanremix',
#   'phonecalls',
#   'prendida'],
#  'maggierogers': ['embers',
#   'deepintheearth',
#   'creatures',
#   'wolves',
#   'bymorning',
#   'aloveletter',
#   'kidslikeus',
#   'satellite',
#   'youembersreprise',
#   'resonantbody',
#   'james',
#   'drift',
#   'bloodballet',
#   'littlejoys',
#   'goodheart',
#   'anybody',
#   'onthepage',
#   'symmetry',
#   'driftdemobonustrack',
#   'colorsong',
#   'alaska',
#   'on+off',
#   'dogyears',
#   'better',
#   'givealittle',
#   'overnight',
#   'theknife',
#   'lighton',
#   'pastlife',
#   'sayit',
#   'fallingwater',
#   'retrograde',
#   'burning',
#   'backinmybody',
#   'alaskasohnremix',
#   'celadonandgold',
#   'loveyouforalongtime',
#   'newsong',
#   'onemoreafternoon',
#   'splitstones',
#   'steadynow',
#   'timmcgraw',
#   'together'],
#  'mabel': ['bedroom',
#   'finderskeepers',
#   'rideordie',
#   'talkaboutforever',
#   'dontcallmeup',
#   'oneshot',
#   'fineline',
#   'mylover',
#   'ringring',
#   'cigarette',
#   'ivy',
#   'comeover',
#   'begging',
#   'lowkey',
#   'passionfruit',
#   'roses',
#   'weapon',
#   'finderskeepersremix',
#   'highexpectationsintro',
#   'badbehaviour',
#   'fml',
#   'wedontsay',
#   'selfishlove',
#   'luckyinterlude',
#   'madlove',
#   'trouble',
#   'putyournameonit',
#   'stckhlmsyndromeinterlude',
#   'okanxietyanthem',
#   'ibelongtome',
#   'highexpectationsoutro',
#   'notsayin',
#   'godisadancerdeluxeeditionbonustrack',
#   'boyfrienddeluxeeditionbonustrack',
#   'finelineremix',
#   'illbehomeforchristmas',
#   'knowmebetter',
#   'loneliesttimeofyear',
#   'myboymytown',
#   'oneshotremix',
#   'thinkingofyou',
#   'thinkingofyoucadenzaremix',
#   'ticktock',
#   'ticktockacoustic',
#   'westten'],
#  'kiiara': ['switchsider',
#   'shedont',
#   'oneday',
#   'dontwantyou',
#   'olddognewbitch',
#   'athousandtimes',
#   'down',
#   'whoknew',
#   '10000hours',
#   'layup',
#   'found',
#   'boodup',
#   'breakfastinbed',
#   'nobodyelse',
#   'myway',
#   'makesmewonder',
#   'anymore',
#   'emotion',
#   'goodbad',
#   'dangerous',
#   'sauce',
#   'whatchamacallit',
#   'cheapshot',
#   'shotclock',
#   'everything',
#   'ownit',
#   'runmymouth',
#   'gutfeeling',
#   'trip',
#   'close',
#   'easy',
#   'nakedbonustrack',
#   'boodupfabolousremix',
#   'booduppliesedition',
#   'boodupremix',
#   'iwish',
#   'justintime',
#   'leftme',
#   'lovemelikethatchampionlove',
#   'norush',
#   'notanotherlovesong',
#   'pedestal',
#   'thoughtsprelude',
#   'whyyoufronting'],
#  'ellamai': ['karate',
#   'gemini',
#   'stole',
#   'cry',
#   'ciaoadios',
#   'alarm',
#   'trigger',
#   'then',
#   'perfect',
#   'friends',
#   'badgirlfriend',
#   'heavy',
#   '2002',
#   'canigetyournumber',
#   'machine',
#   'breathingfiredeluxeeditionbonustrack',
#   'somepeopledeluxeeditionbonustrack',
#   'usedtoloveyoudeluxeeditionbonustrack',
#   'peakdeluxeeditionbonustrack',
#   'rockabyedeluxeeditionbonustrack',
#   'alarmnaughtyboyremix',
#   'birthday',
#   'boy',
#   'ciaoadiosjillionaireremix',
#   'dearmrsprimeminister',
#   'doitright',
#   'dontkillmyvibe',
#   'dontplay',
#   'eitherway',
#   'friendsaboogiewitdahoodieremix',
#   'gentleman',
#   'her',
#   'leavegetout',
#   'notalovesong',
#   'peakstripped',
#   'perfecttome',
#   'problems',
#   'rewritethestars',
#   'thinkofchristmasfrom"happiestseason"soundtrack',
#   'tobeyoung',
#   'waytoolong'],
#  'annemarie': ['seventeen',
#   'here',
#   'outlaws',
#   'imyours',
#   'fourpinkwalls',
#   'wildthings',
#   'stone',
#   'overdose',
#   'stars',
#   'scarstoyourbeautiful',
#   'here200amversion',
#   'riveroftears',
#   'mysong',
#   'growingpains',
#   'nottoday',
#   'idontwantto',
#   '7days',
#   'trustmylonely',
#   'whereverilive',
#   'allweknow',
#   'alittlemore',
#   'comfortable',
#   'nintendogame',
#   'outoflove',
#   'girlnextdoor',
#   'mykind',
#   'easiersaid',
#   'growingpainsreprise',
#   'ready',
#   'whatsonyourmind',
#   'likeyou',
#   'okayokay',
#   'rootingforyou',
#   'october',
#   'makeittochristmasstripped',
#   'thechristmassong',
#   'theonlythingmissing',
#   'moodysmoodforlovelive',
#   'breathin',
#   'drewbarrymore',
#   'hereremix',
#   'howfarillgofrom"moana"soundtrack',
#   'ichoosefrom"thewilloughbys"soundtrack',
#   'iguessthatswhytheycallittheblues',
#   'imlikeabird',
#   'imyoursdemo',
#   'makeittochristmas',
#   'querermejorspanglishversion',
#   'theothersidefrom"thegetdownpt2"soundtrack',
#   'wildthingsremix'],
#  'alessiacara': ['issues',
#   'uhhuh',
#   'worstinme',
#   'makeituptoyou',
#   'justdoit',
#   'pink',
#   'dontwannathink',
#   'anxiety',
#   'intoyou',
#   'happy',
#   'deep',
#   'apple',
#   'whatatime',
#   '17',
#   'fallingforboys',
#   'hurtagain',
#   'worktoomuch',
#   'body',
#   'priest',
#   'fuckedupkinda',
#   'shouldnthavesaidit',
#   'allyourexes',
#   'areyoufrom"fiftyshadesfreed"soundtrack',
#   'giveittoyoufrom"songland"soundtrack',
#   'hearttobreak',
#   'heavenfrom"fiftyshadesfreed"soundtrack',
#   'icarus',
#   'ifyouneedme',
#   'inthisplacefrom"ralphbreakstheinternet"soundtrack',
#   'jump',
#   'kissininthecold',
#   'lielikethis',
#   'little2much',
#   'peerpressure',
#   'symphony'],
#  'juliamichaels': ['stained',
#   'eyelashes',
#   'allinmyhead',
#   'confetti',
#   'celestial',
#   'upsidedown',
#   'rocket',
#   'dearnoone',
#   'treasure',
#   'paperhearts',
#   'daydream',
#   'whereibelongintro',
#   'unbreakablesmile',
#   'nobodylove',
#   'expensive',
#   'shouldvebeenus',
#   'firstheartbreak',
#   'iwasmadeforlovingyou',
#   'citydove',
#   'talk',
#   'funnylive',
#   'artoflettingyougo',
#   'californialovers',
#   'fallingslow',
#   'anyway',
#   'dearnooneitunesbonustrack',
#   'beautifulthingsitunesbonustrack',
#   'hollowreissuebonustrack',
#   'somethingbeautifulreissuebonustrack',
#   'bottleduptargetbonustrack',
#   'personaltargetbonustrack',
#   'masterpiece',
#   'helpustolove',
#   'sunday',
#   'justassure',
#   'psalm42',
#   'questions',
#   'neveralone',
#   'soulsanthemitiswell',
#   'coffee',
#   '12161992',
#   'changeyourmind',
#   'language',
#   '2places',
#   '8281997',
#   'kidiusedtoknow',
#   'prettyfades',
#   'sorrywouldgoalongway',
#   'actress',
#   'thelie',
#   'untilithinkofyou',
#   '3261994',
#   'yourwords',
#   'beforethedawn',
#   'untilforevertargetbonustrack',
#   'minutetomyselftargetbonustrack',
#   'value',
#   'donttakemehome',
#   'timeflies',
#   'unbothered',
#   'glad',
#   'silentnight',
#   '25th',
#   'christmastimeishere',
#   'joytotheworldjoyfuljoyful',
#   'sleighride',
#   'oholynight',
#   'giftthatkeepsongiving',
#   'letitsnow',
#   'ocomeocomeemmanuelocomeallyefaithful',
#   'gotellitonthemountain',
#   'thischristmas',
#   'hallelujahfrom"sing"soundtrack',
#   'alliwantforchristmasisyou',
#   'alwaysloveyou',
#   'angelswehaveheardonhigh',
#   'blinkofaneye',
#   'bringmehome',
#   'colorsofthewindfrom"welovedisney"compilation',
#   'dead',
#   'design',
#   'dontyouworryboutathingfrom"sing"soundtrack',
#   'elegant',
#   'favoritehello',
#   'fillaheart',
#   'funny',
#   'generation',
#   'hopegarden',
#   'kidagainonchristmas',
#   'limelight',
#   'lostinyou',
#   'lullabyrendition',
#   'mrmusic',
#   'reachyourheart',
#   'road',
#   'silentfrom"thegiver"soundtrack',
#   'suitandtie',
#   'taylorswiftmedley',
#   'thebravestone',
#   'together',
#   'tonguetied',
#   'wings',
#   'worthit',
#   'youcaughtme'],
#  'torikelly': ['aintnoway',
#   'dancewithyou',
#   'gettogether',
#   'crush',
#   'sobeit',
#   'truelove',
#   'wonderland',
#   'thiscouldbelove',
#   'feelingyou',
#   'thinkingaboutyou',
#   'solostar',
#   'skyaway',
#   'naive',
#   'godgivenname',
#   'tony',
#   'dancinginthedark',
#   'wouldvebeentheone',
#   'sandcastledisco',
#   'idecided',
#   'valentinesday',
#   '6oclockblues',
#   'odetomarvin',
#   'itoldyouso',
#   'cosmicjourney',
#   'thisbird',
#   'idecidedpart2',
#   'whitepicketdreamsitunesbonustrack',
#   'champagnechroniknightcapcircuitcityeditionbonustrack',
#   'losingyou',
#   'somethingsneverseemtofuckingwork',
#   'lockedinclosets',
#   'loversintheparkinglot',
#   'dontletmedown',
#   'lookgoodwithtrouble',
#   'badgirlsverdineversion',
#   'rise',
#   'weary',
#   'thegloryisinyouinterlude',
#   'cranesinthesky',
#   'dadwasmadinterlude',
#   'mad',
#   'dontyouwait',
#   'tinataughtmeinterlude',
#   'donttouchmyhair',
#   'thismomentinterlude',
#   'wheredowego',
#   'forusbyusinterlude',
#   'fubu',
#   'borderlineanodetoselfcare',
#   'igotsomuchmagicyoucanhaveitinterlude',
#   'junie',
#   'nolimitsinterlude',
#   'dontwishmewell',
#   'pedestalsinterlude',
#   'scales',
#   'closingthechosenones',
#   'thingsiimagined',
#   'smcgregorinterlude',
#   'downwiththeclique',
#   'waytotheshow',
#   'caniholdthemicinterlude',
#   'stayflo',
#   'dreams',
#   'nothingwithoutintentioninterlude',
#   'almeda',
#   'timeis',
#   'myskinmylogo',
#   'wedealwiththefreaknintermission',
#   'jerrod',
#   'binz',
#   'beltway',
#   'exitscottinterlude',
#   'soundofrain',
#   'notscrewed!interlude',
#   'imawitness',
#   'cranesintheskyremix',
#   'fucktheindustrysignedsincerely',
#   'leftsidedrive']}

# %%
# url to scrape the lyrics from
base_url = "https://www.azlyrics.com/lyrics/{}/{}.html"

# %% [markdown]
# In the code below I use Zyte's autoextract package in order to scrape the song lyrics from AZ-lyrics.

# %%
from autoextract.sync import request_raw

# creating the empty dictionary for artists, songs, and lyrics
lyrics_dict = {'lyrics': [], 'song': [], 'artist': []}

# looping through each artist
for artists in pop_songs_dict:
    
    # looping through each song
    for songs in pop_songs_dict[artists]:
        
        # changing the url each time with the next song and artist
        final_url = base_url.format(artists, songs)
        
         # the webscraping part. I use a try statement so 
        # that the loop does not stop if it fails to collect some lyrics
        try:
            query = [{
                'url': final_url,
                'pageType': 'article'
            }]
            results = request_raw(query, api_key='e5e16db9e885448eac36b4d6f130cd61')
            
            # getting just the article body (the lyrics themselves)
            lyric = results[0]['article']['articleBody']
            
            # splitting the lyrics into an array of lyric lines
            cleaned_array = lyric.split('\n')
            
            # appending the data to the dictionary
            lyrics_dict['lyrics'].append(cleaned_array)
            lyrics_dict['song'].append(songs)
            lyrics_dict['artist'].append(artists)
            
            # confirmation and update statement
            print("# lyrics acquired: ", len(lyrics_dict['song']))
        except: 
            print("Missed one, but I'll keep going...")
# Out:
# # lyrics acquired:  1
# # lyrics acquired:  2
# # lyrics acquired:  3
# # lyrics acquired:  4
# # lyrics acquired:  5
# # lyrics acquired:  6
# # lyrics acquired:  7
# # lyrics acquired:  8
# # lyrics acquired:  9
# # lyrics acquired:  10
# # lyrics acquired:  11
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# # lyrics acquired:  12
# # lyrics acquired:  13
# # lyrics acquired:  14
# # lyrics acquired:  15
# # lyrics acquired:  16
# # lyrics acquired:  17
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# # lyrics acquired:  18
# # lyrics acquired:  19
# # lyrics acquired:  20
# # lyrics acquired:  21
# # lyrics acquired:  22
# # lyrics acquired:  23
# # lyrics acquired:  24
# # lyrics acquired:  25
# # lyrics acquired:  26
# # lyrics acquired:  27
# Missed one, but I'll keep going...
# # lyrics acquired:  28
# # lyrics acquired:  29
# # lyrics acquired:  30
# Missed one, but I'll keep going...
# # lyrics acquired:  31
# # lyrics acquired:  32
# # lyrics acquired:  33
# # lyrics acquired:  34
# # lyrics acquired:  35
# # lyrics acquired:  36
# # lyrics acquired:  37
# # lyrics acquired:  38
# # lyrics acquired:  39
# # lyrics acquired:  40
# # lyrics acquired:  41
# # lyrics acquired:  42
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# # lyrics acquired:  43
# # lyrics acquired:  44
# # lyrics acquired:  45
# # lyrics acquired:  46
# # lyrics acquired:  47
# # lyrics acquired:  48
# # lyrics acquired:  49
# # lyrics acquired:  50
# # lyrics acquired:  51
# # lyrics acquired:  52
# # lyrics acquired:  53
# # lyrics acquired:  54
# # lyrics acquired:  55
# # lyrics acquired:  56
# # lyrics acquired:  57
# # lyrics acquired:  58
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# # lyrics acquired:  59
# # lyrics acquired:  60
# # lyrics acquired:  61
# # lyrics acquired:  62
# # lyrics acquired:  63
# # lyrics acquired:  64
# # lyrics acquired:  65
# # lyrics acquired:  66
# # lyrics acquired:  67
# # lyrics acquired:  68
# # lyrics acquired:  69
# # lyrics acquired:  70
# # lyrics acquired:  71
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# # lyrics acquired:  72
# # lyrics acquired:  73
# # lyrics acquired:  74
# # lyrics acquired:  75
# # lyrics acquired:  76
# # lyrics acquired:  77
# # lyrics acquired:  78
# # lyrics acquired:  79
# # lyrics acquired:  80
# # lyrics acquired:  81
# # lyrics acquired:  82
# # lyrics acquired:  83
# # lyrics acquired:  84
# # lyrics acquired:  85
# # lyrics acquired:  86
# # lyrics acquired:  87
# # lyrics acquired:  88
# # lyrics acquired:  89
# # lyrics acquired:  90
# # lyrics acquired:  91
# # lyrics acquired:  92
# Missed one, but I'll keep going...
# # lyrics acquired:  93
# # lyrics acquired:  94
# # lyrics acquired:  95
# # lyrics acquired:  96
# # lyrics acquired:  97
# # lyrics acquired:  98
# # lyrics acquired:  99
# # lyrics acquired:  100
# Missed one, but I'll keep going...
# # lyrics acquired:  101
# # lyrics acquired:  102
# # lyrics acquired:  103
# # lyrics acquired:  104
# # lyrics acquired:  105
# # lyrics acquired:  106
# # lyrics acquired:  107
# # lyrics acquired:  108
# # lyrics acquired:  109
# # lyrics acquired:  110
# # lyrics acquired:  111
# # lyrics acquired:  112
# # lyrics acquired:  113
# # lyrics acquired:  114
# # lyrics acquired:  115
# # lyrics acquired:  116
# # lyrics acquired:  117
# # lyrics acquired:  118
# Missed one, but I'll keep going...
# # lyrics acquired:  119
# # lyrics acquired:  120
# # lyrics acquired:  121
# # lyrics acquired:  122
# # lyrics acquired:  123
# # lyrics acquired:  124
# # lyrics acquired:  125
# # lyrics acquired:  126
# # lyrics acquired:  127
# # lyrics acquired:  128
# # lyrics acquired:  129
# # lyrics acquired:  130
# # lyrics acquired:  131
# # lyrics acquired:  132
# # lyrics acquired:  133
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# # lyrics acquired:  134
# # lyrics acquired:  135
# # lyrics acquired:  136
# # lyrics acquired:  137
# # lyrics acquired:  138
# # lyrics acquired:  139
# # lyrics acquired:  140
# # lyrics acquired:  141
# # lyrics acquired:  142
# # lyrics acquired:  143
# Missed one, but I'll keep going...
# # lyrics acquired:  144
# # lyrics acquired:  145
# # lyrics acquired:  146
# # lyrics acquired:  147
# Missed one, but I'll keep going...
# # lyrics acquired:  148
# # lyrics acquired:  149
# # lyrics acquired:  150
# # lyrics acquired:  151
# Missed one, but I'll keep going...
# # lyrics acquired:  152
# # lyrics acquired:  153
# # lyrics acquired:  154
# # lyrics acquired:  155
# # lyrics acquired:  156
# Missed one, but I'll keep going...
# # lyrics acquired:  157
# # lyrics acquired:  158
# # lyrics acquired:  159
# # lyrics acquired:  160
# # lyrics acquired:  161
# # lyrics acquired:  162
# # lyrics acquired:  163
# # lyrics acquired:  164
# Missed one, but I'll keep going...
# # lyrics acquired:  165
# # lyrics acquired:  166
# Missed one, but I'll keep going...
# # lyrics acquired:  167
# # lyrics acquired:  168
# # lyrics acquired:  169
# # lyrics acquired:  170
# Missed one, but I'll keep going...
# # lyrics acquired:  171
# # lyrics acquired:  172
# # lyrics acquired:  173
# # lyrics acquired:  174
# # lyrics acquired:  175
# # lyrics acquired:  176
# # lyrics acquired:  177
# Missed one, but I'll keep going...
# # lyrics acquired:  178
# # lyrics acquired:  179
# # lyrics acquired:  180
# # lyrics acquired:  181
# # lyrics acquired:  182
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# # lyrics acquired:  183
# # lyrics acquired:  184
# # lyrics acquired:  185
# # lyrics acquired:  186
# # lyrics acquired:  187
# # lyrics acquired:  188
# Missed one, but I'll keep going...
# # lyrics acquired:  189
# # lyrics acquired:  190
# # lyrics acquired:  191
# # lyrics acquired:  192
# Missed one, but I'll keep going...
# # lyrics acquired:  193
# # lyrics acquired:  194
# # lyrics acquired:  195
# # lyrics acquired:  196
# # lyrics acquired:  197
# # lyrics acquired:  198
# # lyrics acquired:  199
# # lyrics acquired:  200
# Missed one, but I'll keep going...
# # lyrics acquired:  201
# # lyrics acquired:  202
# # lyrics acquired:  203
# # lyrics acquired:  204
# # lyrics acquired:  205
# # lyrics acquired:  206
# Missed one, but I'll keep going...
# # lyrics acquired:  207
# # lyrics acquired:  208
# # lyrics acquired:  209
# # lyrics acquired:  210
# # lyrics acquired:  211
# # lyrics acquired:  212
# # lyrics acquired:  213
# # lyrics acquired:  214
# # lyrics acquired:  215
# # lyrics acquired:  216
# # lyrics acquired:  217
# # lyrics acquired:  218
# # lyrics acquired:  219
# # lyrics acquired:  220
# Missed one, but I'll keep going...
# # lyrics acquired:  221
# # lyrics acquired:  222
# # lyrics acquired:  223
# # lyrics acquired:  224
# # lyrics acquired:  225
# # lyrics acquired:  226
# # lyrics acquired:  227
# # lyrics acquired:  228
# Missed one, but I'll keep going...
# # lyrics acquired:  229
# # lyrics acquired:  230
# # lyrics acquired:  231
# # lyrics acquired:  232
# # lyrics acquired:  233
# # lyrics acquired:  234
# # lyrics acquired:  235
# # lyrics acquired:  236
# Missed one, but I'll keep going...
# # lyrics acquired:  237
# # lyrics acquired:  238
# # lyrics acquired:  239
# # lyrics acquired:  240
# # lyrics acquired:  241
# # lyrics acquired:  242
# # lyrics acquired:  243
# # lyrics acquired:  244
# # lyrics acquired:  245
# # lyrics acquired:  246
# # lyrics acquired:  247
# # lyrics acquired:  248
# Missed one, but I'll keep going...
# # lyrics acquired:  249
# # lyrics acquired:  250
# # lyrics acquired:  251
# # lyrics acquired:  252
# # lyrics acquired:  253
# # lyrics acquired:  254
# # lyrics acquired:  255
# # lyrics acquired:  256
# # lyrics acquired:  257
# # lyrics acquired:  258
# # lyrics acquired:  259
# Missed one, but I'll keep going...
# # lyrics acquired:  260
# # lyrics acquired:  261
# # lyrics acquired:  262
# # lyrics acquired:  263
# # lyrics acquired:  264
# # lyrics acquired:  265
# # lyrics acquired:  266
# # lyrics acquired:  267
# # lyrics acquired:  268
# # lyrics acquired:  269
# # lyrics acquired:  270
# # lyrics acquired:  271
# # lyrics acquired:  272
# # lyrics acquired:  273
# # lyrics acquired:  274
# # lyrics acquired:  275
# # lyrics acquired:  276
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# # lyrics acquired:  277
# # lyrics acquired:  278
# # lyrics acquired:  279
# # lyrics acquired:  280
# # lyrics acquired:  281
# # lyrics acquired:  282
# # lyrics acquired:  283
# # lyrics acquired:  284
# # lyrics acquired:  285
# # lyrics acquired:  286
# # lyrics acquired:  287
# # lyrics acquired:  288
# # lyrics acquired:  289
# # lyrics acquired:  290
# Missed one, but I'll keep going...
# # lyrics acquired:  291
# # lyrics acquired:  292
# # lyrics acquired:  293
# # lyrics acquired:  294
# # lyrics acquired:  295
# # lyrics acquired:  296
# # lyrics acquired:  297
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# # lyrics acquired:  298
# # lyrics acquired:  299
# Missed one, but I'll keep going...
# # lyrics acquired:  300
# # lyrics acquired:  301
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# # lyrics acquired:  302
# # lyrics acquired:  303
# # lyrics acquired:  304
# # lyrics acquired:  305
# # lyrics acquired:  306
# Missed one, but I'll keep going...
# # lyrics acquired:  307
# # lyrics acquired:  308
# # lyrics acquired:  309
# # lyrics acquired:  310
# # lyrics acquired:  311
# # lyrics acquired:  312
# Missed one, but I'll keep going...
# # lyrics acquired:  313
# # lyrics acquired:  314
# # lyrics acquired:  315
# # lyrics acquired:  316
# # lyrics acquired:  317
# # lyrics acquired:  318
# # lyrics acquired:  319
# # lyrics acquired:  320
# Missed one, but I'll keep going...
# # lyrics acquired:  321
# # lyrics acquired:  322
# # lyrics acquired:  323
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# # lyrics acquired:  324
# # lyrics acquired:  325
# # lyrics acquired:  326
# # lyrics acquired:  327
# # lyrics acquired:  328
# # lyrics acquired:  329
# # lyrics acquired:  330
# # lyrics acquired:  331
# # lyrics acquired:  332
# # lyrics acquired:  333
# # lyrics acquired:  334
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# # lyrics acquired:  335
# # lyrics acquired:  336
# # lyrics acquired:  337
# # lyrics acquired:  338
# # lyrics acquired:  339
# # lyrics acquired:  340
# # lyrics acquired:  341
# # lyrics acquired:  342
# # lyrics acquired:  343
# # lyrics acquired:  344
# # lyrics acquired:  345
# # lyrics acquired:  346
# # lyrics acquired:  347
# # lyrics acquired:  348
# # lyrics acquired:  349
# # lyrics acquired:  350
# # lyrics acquired:  351
# # lyrics acquired:  352
# # lyrics acquired:  353
# # lyrics acquired:  354
# # lyrics acquired:  355
# # lyrics acquired:  356
# # lyrics acquired:  357
# # lyrics acquired:  358
# # lyrics acquired:  359
# # lyrics acquired:  360
# # lyrics acquired:  361
# # lyrics acquired:  362
# # lyrics acquired:  363
# Missed one, but I'll keep going...
# # lyrics acquired:  364
# # lyrics acquired:  365
# # lyrics acquired:  366
# # lyrics acquired:  367
# # lyrics acquired:  368
# # lyrics acquired:  369
# # lyrics acquired:  370
# # lyrics acquired:  371
# # lyrics acquired:  372
# # lyrics acquired:  373
# # lyrics acquired:  374
# # lyrics acquired:  375
# # lyrics acquired:  376
# # lyrics acquired:  377
# # lyrics acquired:  378
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# # lyrics acquired:  379
# # lyrics acquired:  380
# # lyrics acquired:  381
# # lyrics acquired:  382
# # lyrics acquired:  383
# # lyrics acquired:  384
# # lyrics acquired:  385
# # lyrics acquired:  386
# # lyrics acquired:  387
# # lyrics acquired:  388
# # lyrics acquired:  389
# # lyrics acquired:  390
# # lyrics acquired:  391
# # lyrics acquired:  392
# # lyrics acquired:  393
# # lyrics acquired:  394
# # lyrics acquired:  395
# Missed one, but I'll keep going...
# # lyrics acquired:  396
# # lyrics acquired:  397
# # lyrics acquired:  398
# # lyrics acquired:  399
# # lyrics acquired:  400
# Missed one, but I'll keep going...
# # lyrics acquired:  401
# # lyrics acquired:  402
# Missed one, but I'll keep going...
# # lyrics acquired:  403
# Missed one, but I'll keep going...
# # lyrics acquired:  404
# # lyrics acquired:  405
# # lyrics acquired:  406
# # lyrics acquired:  407
# # lyrics acquired:  408
# # lyrics acquired:  409
# # lyrics acquired:  410
# # lyrics acquired:  411
# # lyrics acquired:  412
# # lyrics acquired:  413
# # lyrics acquired:  414
# # lyrics acquired:  415
# # lyrics acquired:  416
# # lyrics acquired:  417
# # lyrics acquired:  418
# # lyrics acquired:  419
# # lyrics acquired:  420
# # lyrics acquired:  421
# # lyrics acquired:  422
# # lyrics acquired:  423
# # lyrics acquired:  424
# # lyrics acquired:  425
# # lyrics acquired:  426
# # lyrics acquired:  427
# # lyrics acquired:  428
# # lyrics acquired:  429
# # lyrics acquired:  430
# # lyrics acquired:  431
# # lyrics acquired:  432
# # lyrics acquired:  433
# # lyrics acquired:  434
# # lyrics acquired:  435
# # lyrics acquired:  436
# # lyrics acquired:  437
# # lyrics acquired:  438
# # lyrics acquired:  439
# # lyrics acquired:  440
# # lyrics acquired:  441
# # lyrics acquired:  442
# # lyrics acquired:  443
# # lyrics acquired:  444
# # lyrics acquired:  445
# # lyrics acquired:  446
# # lyrics acquired:  447
# # lyrics acquired:  448
# # lyrics acquired:  449
# # lyrics acquired:  450
# # lyrics acquired:  451
# # lyrics acquired:  452
# # lyrics acquired:  453
# Missed one, but I'll keep going...
# # lyrics acquired:  454
# # lyrics acquired:  455
# Missed one, but I'll keep going...
# # lyrics acquired:  456
# # lyrics acquired:  457
# # lyrics acquired:  458
# # lyrics acquired:  459
# # lyrics acquired:  460
# # lyrics acquired:  461
# # lyrics acquired:  462
# # lyrics acquired:  463
# # lyrics acquired:  464
# Missed one, but I'll keep going...
# # lyrics acquired:  465
# # lyrics acquired:  466
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# # lyrics acquired:  467
# # lyrics acquired:  468
# # lyrics acquired:  469
# # lyrics acquired:  470
# # lyrics acquired:  471
# # lyrics acquired:  472
# # lyrics acquired:  473
# # lyrics acquired:  474
# # lyrics acquired:  475
# # lyrics acquired:  476
# # lyrics acquired:  477
# # lyrics acquired:  478
# # lyrics acquired:  479
# # lyrics acquired:  480
# # lyrics acquired:  481
# # lyrics acquired:  482
# # lyrics acquired:  483
# # lyrics acquired:  484
# # lyrics acquired:  485
# # lyrics acquired:  486
# Missed one, but I'll keep going...
# # lyrics acquired:  487
# # lyrics acquired:  488
# # lyrics acquired:  489
# # lyrics acquired:  490
# # lyrics acquired:  491
# # lyrics acquired:  492
# # lyrics acquired:  493
# # lyrics acquired:  494
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# # lyrics acquired:  495
# # lyrics acquired:  496
# # lyrics acquired:  497
# # lyrics acquired:  498
# # lyrics acquired:  499
# # lyrics acquired:  500
# # lyrics acquired:  501
# # lyrics acquired:  502
# # lyrics acquired:  503
# # lyrics acquired:  504
# # lyrics acquired:  505
# # lyrics acquired:  506
# # lyrics acquired:  507
# # lyrics acquired:  508
# # lyrics acquired:  509
# # lyrics acquired:  510
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# # lyrics acquired:  511
# # lyrics acquired:  512
# # lyrics acquired:  513
# # lyrics acquired:  514
# Missed one, but I'll keep going...
# # lyrics acquired:  515
# # lyrics acquired:  516
# # lyrics acquired:  517
# # lyrics acquired:  518
# # lyrics acquired:  519
# # lyrics acquired:  520
# # lyrics acquired:  521
# # lyrics acquired:  522
# # lyrics acquired:  523
# # lyrics acquired:  524
# # lyrics acquired:  525
# # lyrics acquired:  526
# # lyrics acquired:  527
# # lyrics acquired:  528
# # lyrics acquired:  529
# # lyrics acquired:  530
# # lyrics acquired:  531
# # lyrics acquired:  532
# # lyrics acquired:  533
# # lyrics acquired:  534
# # lyrics acquired:  535
# # lyrics acquired:  536
# # lyrics acquired:  537
# Missed one, but I'll keep going...
# # lyrics acquired:  538
# # lyrics acquired:  539
# # lyrics acquired:  540
# # lyrics acquired:  541
# # lyrics acquired:  542
# # lyrics acquired:  543
# # lyrics acquired:  544
# # lyrics acquired:  545
# # lyrics acquired:  546
# # lyrics acquired:  547
# # lyrics acquired:  548
# # lyrics acquired:  549
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# # lyrics acquired:  550
# Missed one, but I'll keep going...
# # lyrics acquired:  551
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# # lyrics acquired:  552
# # lyrics acquired:  553
# Missed one, but I'll keep going...
# # lyrics acquired:  554
# # lyrics acquired:  555
# Missed one, but I'll keep going...
# # lyrics acquired:  556
# # lyrics acquired:  557
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# # lyrics acquired:  558
# # lyrics acquired:  559
# Missed one, but I'll keep going...
# # lyrics acquired:  560
# # lyrics acquired:  561
# # lyrics acquired:  562
# # lyrics acquired:  563
# # lyrics acquired:  564
# # lyrics acquired:  565
# # lyrics acquired:  566
# # lyrics acquired:  567
# # lyrics acquired:  568
# # lyrics acquired:  569
# Missed one, but I'll keep going...
# # lyrics acquired:  570
# # lyrics acquired:  571
# # lyrics acquired:  572
# # lyrics acquired:  573
# # lyrics acquired:  574
# Missed one, but I'll keep going...
# # lyrics acquired:  575
# # lyrics acquired:  576
# # lyrics acquired:  577
# # lyrics acquired:  578
# # lyrics acquired:  579
# # lyrics acquired:  580
# # lyrics acquired:  581
# # lyrics acquired:  582
# # lyrics acquired:  583
# # lyrics acquired:  584
# Missed one, but I'll keep going...
# # lyrics acquired:  585
# # lyrics acquired:  586
# # lyrics acquired:  587
# Missed one, but I'll keep going...
# # lyrics acquired:  588
# # lyrics acquired:  589
# # lyrics acquired:  590
# # lyrics acquired:  591
# # lyrics acquired:  592
# # lyrics acquired:  593
# # lyrics acquired:  594
# Missed one, but I'll keep going...
# # lyrics acquired:  595
# # lyrics acquired:  596
# # lyrics acquired:  597
# # lyrics acquired:  598
# # lyrics acquired:  599
# # lyrics acquired:  600
# # lyrics acquired:  601
# # lyrics acquired:  602
# Missed one, but I'll keep going...
# # lyrics acquired:  603
# # lyrics acquired:  604
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# # lyrics acquired:  605
# # lyrics acquired:  606
# # lyrics acquired:  607
# Missed one, but I'll keep going...
# # lyrics acquired:  608
# # lyrics acquired:  609
# # lyrics acquired:  610
# # lyrics acquired:  611
# # lyrics acquired:  612
# # lyrics acquired:  613
# # lyrics acquired:  614
# Missed one, but I'll keep going...
# # lyrics acquired:  615
# # lyrics acquired:  616
# # lyrics acquired:  617
# # lyrics acquired:  618
# # lyrics acquired:  619
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# # lyrics acquired:  620
# # lyrics acquired:  621
# # lyrics acquired:  622
# # lyrics acquired:  623
# # lyrics acquired:  624
# # lyrics acquired:  625
# # lyrics acquired:  626
# # lyrics acquired:  627
# # lyrics acquired:  628
# # lyrics acquired:  629
# # lyrics acquired:  630
# # lyrics acquired:  631
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# # lyrics acquired:  632
# # lyrics acquired:  633
# # lyrics acquired:  634
# # lyrics acquired:  635
# # lyrics acquired:  636
# # lyrics acquired:  637
# # lyrics acquired:  638
# # lyrics acquired:  639
# # lyrics acquired:  640
# Missed one, but I'll keep going...
# # lyrics acquired:  641
# # lyrics acquired:  642
# # lyrics acquired:  643
# # lyrics acquired:  644
# # lyrics acquired:  645
# # lyrics acquired:  646
# # lyrics acquired:  647
# # lyrics acquired:  648
# # lyrics acquired:  649
# # lyrics acquired:  650
# # lyrics acquired:  651
# # lyrics acquired:  652
# # lyrics acquired:  653
# # lyrics acquired:  654
# # lyrics acquired:  655
# # lyrics acquired:  656
# # lyrics acquired:  657
# # lyrics acquired:  658
# # lyrics acquired:  659
# # lyrics acquired:  660
# # lyrics acquired:  661
# # lyrics acquired:  662
# # lyrics acquired:  663
# # lyrics acquired:  664
# # lyrics acquired:  665
# Missed one, but I'll keep going...
# # lyrics acquired:  666
# # lyrics acquired:  667
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# # lyrics acquired:  668
# # lyrics acquired:  669
# # lyrics acquired:  670
# # lyrics acquired:  671
# # lyrics acquired:  672
# # lyrics acquired:  673
# # lyrics acquired:  674
# # lyrics acquired:  675
# # lyrics acquired:  676
# # lyrics acquired:  677
# # lyrics acquired:  678
# # lyrics acquired:  679
# # lyrics acquired:  680
# # lyrics acquired:  681
# # lyrics acquired:  682
# # lyrics acquired:  683
# # lyrics acquired:  684
# # lyrics acquired:  685
# # lyrics acquired:  686
# # lyrics acquired:  687
# # lyrics acquired:  688
# # lyrics acquired:  689
# # lyrics acquired:  690
# # lyrics acquired:  691
# # lyrics acquired:  692
# # lyrics acquired:  693
# # lyrics acquired:  694
# # lyrics acquired:  695
# # lyrics acquired:  696
# # lyrics acquired:  697
# # lyrics acquired:  698
# # lyrics acquired:  699
# # lyrics acquired:  700
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# # lyrics acquired:  701
# # lyrics acquired:  702
# # lyrics acquired:  703
# # lyrics acquired:  704
# # lyrics acquired:  705
# # lyrics acquired:  706
# Missed one, but I'll keep going...
# # lyrics acquired:  707
# # lyrics acquired:  708
# # lyrics acquired:  709
# # lyrics acquired:  710
# Missed one, but I'll keep going...
# # lyrics acquired:  711
# # lyrics acquired:  712
# # lyrics acquired:  713
# # lyrics acquired:  714
# # lyrics acquired:  715
# # lyrics acquired:  716
# # lyrics acquired:  717
# Missed one, but I'll keep going...
# # lyrics acquired:  718
# Missed one, but I'll keep going...
# # lyrics acquired:  719
# # lyrics acquired:  720
# # lyrics acquired:  721
# # lyrics acquired:  722
# # lyrics acquired:  723
# # lyrics acquired:  724
# # lyrics acquired:  725
# # lyrics acquired:  726
# # lyrics acquired:  727
# # lyrics acquired:  728
# # lyrics acquired:  729
# # lyrics acquired:  730
# # lyrics acquired:  731
# Missed one, but I'll keep going...
# # lyrics acquired:  732
# # lyrics acquired:  733
# # lyrics acquired:  734
# # lyrics acquired:  735
# # lyrics acquired:  736
# # lyrics acquired:  737
# # lyrics acquired:  738
# # lyrics acquired:  739
# # lyrics acquired:  740
# # lyrics acquired:  741
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# # lyrics acquired:  742
# # lyrics acquired:  743
# # lyrics acquired:  744
# # lyrics acquired:  745
# # lyrics acquired:  746
# # lyrics acquired:  747
# # lyrics acquired:  748
# # lyrics acquired:  749
# # lyrics acquired:  750
# # lyrics acquired:  751
# # lyrics acquired:  752
# Missed one, but I'll keep going...
# # lyrics acquired:  753
# # lyrics acquired:  754
# # lyrics acquired:  755
# Missed one, but I'll keep going...
# # lyrics acquired:  756
# # lyrics acquired:  757
# # lyrics acquired:  758
# # lyrics acquired:  759
# Missed one, but I'll keep going...
# # lyrics acquired:  760
# # lyrics acquired:  761
# # lyrics acquired:  762
# # lyrics acquired:  763
# # lyrics acquired:  764
# # lyrics acquired:  765
# # lyrics acquired:  766
# # lyrics acquired:  767
# # lyrics acquired:  768
# # lyrics acquired:  769
# # lyrics acquired:  770
# # lyrics acquired:  771
# # lyrics acquired:  772
# # lyrics acquired:  773
# # lyrics acquired:  774
# # lyrics acquired:  775
# Missed one, but I'll keep going...
# # lyrics acquired:  776
# # lyrics acquired:  777
# # lyrics acquired:  778
# # lyrics acquired:  779
# # lyrics acquired:  780
# # lyrics acquired:  781
# # lyrics acquired:  782
# # lyrics acquired:  783
# # lyrics acquired:  784
# # lyrics acquired:  785
# # lyrics acquired:  786
# # lyrics acquired:  787
# # lyrics acquired:  788
# # lyrics acquired:  789
# # lyrics acquired:  790
# # lyrics acquired:  791
# # lyrics acquired:  792
# # lyrics acquired:  793
# # lyrics acquired:  794
# # lyrics acquired:  795
# # lyrics acquired:  796
# # lyrics acquired:  797
# # lyrics acquired:  798
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# # lyrics acquired:  799
# # lyrics acquired:  800
# # lyrics acquired:  801
# # lyrics acquired:  802
# # lyrics acquired:  803
# # lyrics acquired:  804
# # lyrics acquired:  805
# # lyrics acquired:  806
# # lyrics acquired:  807
# # lyrics acquired:  808
# # lyrics acquired:  809
# # lyrics acquired:  810
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# # lyrics acquired:  811
# # lyrics acquired:  812
# # lyrics acquired:  813
# # lyrics acquired:  814
# # lyrics acquired:  815
# # lyrics acquired:  816
# # lyrics acquired:  817
# # lyrics acquired:  818
# # lyrics acquired:  819
# # lyrics acquired:  820
# # lyrics acquired:  821
# # lyrics acquired:  822
# # lyrics acquired:  823
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# # lyrics acquired:  824
# # lyrics acquired:  825
# # lyrics acquired:  826
# # lyrics acquired:  827
# Missed one, but I'll keep going...
# # lyrics acquired:  828
# # lyrics acquired:  829
# # lyrics acquired:  830
# # lyrics acquired:  831
# # lyrics acquired:  832
# # lyrics acquired:  833
# # lyrics acquired:  834
# # lyrics acquired:  835
# Missed one, but I'll keep going...
# # lyrics acquired:  836
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# # lyrics acquired:  837
# # lyrics acquired:  838
# # lyrics acquired:  839
# # lyrics acquired:  840
# # lyrics acquired:  841
# # lyrics acquired:  842
# # lyrics acquired:  843
# # lyrics acquired:  844
# # lyrics acquired:  845
# # lyrics acquired:  846
# # lyrics acquired:  847
# # lyrics acquired:  848
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# # lyrics acquired:  849
# Missed one, but I'll keep going...
# # lyrics acquired:  850
# # lyrics acquired:  851
# # lyrics acquired:  852
# # lyrics acquired:  853
# Missed one, but I'll keep going...
# # lyrics acquired:  854
# # lyrics acquired:  855
# # lyrics acquired:  856
# # lyrics acquired:  857
# # lyrics acquired:  858
# # lyrics acquired:  859
# # lyrics acquired:  860
# # lyrics acquired:  861
# # lyrics acquired:  862
# # lyrics acquired:  863
# # lyrics acquired:  864
# # lyrics acquired:  865
# # lyrics acquired:  866
# # lyrics acquired:  867
# Missed one, but I'll keep going...
# # lyrics acquired:  868
# # lyrics acquired:  869
# # lyrics acquired:  870
# # lyrics acquired:  871
# # lyrics acquired:  872
# # lyrics acquired:  873
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# # lyrics acquired:  874
# # lyrics acquired:  875
# # lyrics acquired:  876
# # lyrics acquired:  877
# # lyrics acquired:  878
# # lyrics acquired:  879
# # lyrics acquired:  880
# # lyrics acquired:  881
# # lyrics acquired:  882
# # lyrics acquired:  883
# # lyrics acquired:  884
# # lyrics acquired:  885
# # lyrics acquired:  886
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# # lyrics acquired:  887
# # lyrics acquired:  888
# # lyrics acquired:  889
# # lyrics acquired:  890
# # lyrics acquired:  891
# # lyrics acquired:  892
# # lyrics acquired:  893
# # lyrics acquired:  894
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# # lyrics acquired:  895
# # lyrics acquired:  896
# # lyrics acquired:  897
# # lyrics acquired:  898
# Missed one, but I'll keep going...
# # lyrics acquired:  899
# # lyrics acquired:  900
# # lyrics acquired:  901
# # lyrics acquired:  902
# # lyrics acquired:  903
# # lyrics acquired:  904
# # lyrics acquired:  905
# # lyrics acquired:  906
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# # lyrics acquired:  907
# # lyrics acquired:  908
# # lyrics acquired:  909
# Missed one, but I'll keep going...
# # lyrics acquired:  910
# Missed one, but I'll keep going...
# # lyrics acquired:  911
# # lyrics acquired:  912
# # lyrics acquired:  913
# # lyrics acquired:  914
# # lyrics acquired:  915
# Missed one, but I'll keep going...
# # lyrics acquired:  916
# Missed one, but I'll keep going...
# # lyrics acquired:  917
# # lyrics acquired:  918
# # lyrics acquired:  919
# # lyrics acquired:  920
# # lyrics acquired:  921
# # lyrics acquired:  922
# # lyrics acquired:  923
# # lyrics acquired:  924
# # lyrics acquired:  925
# # lyrics acquired:  926
# # lyrics acquired:  927
# # lyrics acquired:  928
# # lyrics acquired:  929
# # lyrics acquired:  930
# # lyrics acquired:  931
# # lyrics acquired:  932
# # lyrics acquired:  933
# # lyrics acquired:  934
# # lyrics acquired:  935
# # lyrics acquired:  936
# # lyrics acquired:  937
# # lyrics acquired:  938
# # lyrics acquired:  939
# # lyrics acquired:  940
# # lyrics acquired:  941
# # lyrics acquired:  942
# # lyrics acquired:  943
# # lyrics acquired:  944
# # lyrics acquired:  945
# # lyrics acquired:  946
# # lyrics acquired:  947
# # lyrics acquired:  948
# # lyrics acquired:  949
# # lyrics acquired:  950
# # lyrics acquired:  951
# # lyrics acquired:  952
# # lyrics acquired:  953
# # lyrics acquired:  954
# # lyrics acquired:  955
# # lyrics acquired:  956
# # lyrics acquired:  957
# # lyrics acquired:  958
# # lyrics acquired:  959
# # lyrics acquired:  960
# # lyrics acquired:  961
# Missed one, but I'll keep going...
# # lyrics acquired:  962
# # lyrics acquired:  963
# # lyrics acquired:  964
# # lyrics acquired:  965
# # lyrics acquired:  966
# # lyrics acquired:  967
# ...
# # lyrics acquired:  6856
# # lyrics acquired:  6857
# # lyrics acquired:  6858
# # lyrics acquired:  6859
# # lyrics acquired:  6860
# # lyrics acquired:  6861
# Missed one, but I'll keep going...
# # lyrics acquired:  6862
# # lyrics acquired:  6863
# # lyrics acquired:  6864
# # lyrics acquired:  6865
# # lyrics acquired:  6866
# # lyrics acquired:  6867
# # lyrics acquired:  6868
# # lyrics acquired:  6869
# # lyrics acquired:  6870
# # lyrics acquired:  6871
# # lyrics acquired:  6872
# # lyrics acquired:  6873
# # lyrics acquired:  6874
# # lyrics acquired:  6875
# # lyrics acquired:  6876
# # lyrics acquired:  6877
# # lyrics acquired:  6878
# # lyrics acquired:  6879
# # lyrics acquired:  6880
# # lyrics acquired:  6881
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# # lyrics acquired:  6882
# # lyrics acquired:  6883
# # lyrics acquired:  6884
# # lyrics acquired:  6885
# # lyrics acquired:  6886
# Missed one, but I'll keep going...
# # lyrics acquired:  6887
# # lyrics acquired:  6888
# Missed one, but I'll keep going...
# # lyrics acquired:  6889
# Missed one, but I'll keep going...
# # lyrics acquired:  6890
# Missed one, but I'll keep going...
# # lyrics acquired:  6891
# # lyrics acquired:  6892
# # lyrics acquired:  6893
# # lyrics acquired:  6894
# # lyrics acquired:  6895
# # lyrics acquired:  6896
# # lyrics acquired:  6897
# # lyrics acquired:  6898
# # lyrics acquired:  6899
# # lyrics acquired:  6900
# Missed one, but I'll keep going...
# # lyrics acquired:  6901
# # lyrics acquired:  6902
# # lyrics acquired:  6903
# # lyrics acquired:  6904
# # lyrics acquired:  6905
# # lyrics acquired:  6906
# # lyrics acquired:  6907
# # lyrics acquired:  6908
# # lyrics acquired:  6909
# Missed one, but I'll keep going...
# # lyrics acquired:  6910
# # lyrics acquired:  6911
# Missed one, but I'll keep going...
# # lyrics acquired:  6912
# # lyrics acquired:  6913
# # lyrics acquired:  6914
# # lyrics acquired:  6915
# # lyrics acquired:  6916
# # lyrics acquired:  6917
# # lyrics acquired:  6918
# # lyrics acquired:  6919
# # lyrics acquired:  6920
# # lyrics acquired:  6921
# # lyrics acquired:  6922
# # lyrics acquired:  6923
# # lyrics acquired:  6924
# Missed one, but I'll keep going...
# # lyrics acquired:  6925
# # lyrics acquired:  6926
# # lyrics acquired:  6927
# # lyrics acquired:  6928
# # lyrics acquired:  6929
# # lyrics acquired:  6930
# # lyrics acquired:  6931
# # lyrics acquired:  6932
# # lyrics acquired:  6933
# # lyrics acquired:  6934
# # lyrics acquired:  6935
# # lyrics acquired:  6936
# # lyrics acquired:  6937
# # lyrics acquired:  6938
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# # lyrics acquired:  6939
# # lyrics acquired:  6940
# # lyrics acquired:  6941
# # lyrics acquired:  6942
# # lyrics acquired:  6943
# # lyrics acquired:  6944
# # lyrics acquired:  6945
# # lyrics acquired:  6946
# # lyrics acquired:  6947
# # lyrics acquired:  6948
# # lyrics acquired:  6949
# # lyrics acquired:  6950
# # lyrics acquired:  6951
# # lyrics acquired:  6952
# # lyrics acquired:  6953
# # lyrics acquired:  6954
# # lyrics acquired:  6955
# # lyrics acquired:  6956
# # lyrics acquired:  6957
# # lyrics acquired:  6958
# # lyrics acquired:  6959
# # lyrics acquired:  6960
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# # lyrics acquired:  6961
# # lyrics acquired:  6962
# # lyrics acquired:  6963
# # lyrics acquired:  6964
# # lyrics acquired:  6965
# # lyrics acquired:  6966
# # lyrics acquired:  6967
# # lyrics acquired:  6968
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...
# Missed one, but I'll keep going...

# %%
# assigning the dictionary to a dataframe in order to take a quick look at the data
pop_lyrics_df = pd.DataFrame({'lyrics':lyrics_dict['lyrics'], 'song':lyrics_dict['song'], 'artist':lyrics_dict['artist']})

# %%
pop_lyrics_df
# Out:
#                                                  lyrics  \
# 0     [He said the way my blue eyes shined, Put thos...
# 1     [State the obvious, I didn't get my perfect fa...
# 2     [Taylor Swift Lyrics, , "Teardrops On My Guita...
# 3     [Taylor Swift Lyrics, , "A Place In This World...
# 4     [You have a way of coming easily to me, And wh...
# ...                                                 ...
# 6963  [Sorry I'm not so merry, But I feel like this ...
# 6964  [Straight up, Tell me everything you've been t...
# 6965  [[Yungen:], Young Mabes, Yungen, One shot, , L...
# 6966  [I'm thinking of you, I'm thinking of you, I'm...
# 6967  [[Mabel:], Why can't I tell if you're into me,...
#
#                            song       artist
# 0                     timmcgraw  taylorswift
# 1                 picturetoburn  taylorswift
# 2           teardropsonmyguitar  taylorswift
# 3             aplaceinthisworld  taylorswift
# 4                     coldasyou  taylorswift
# ...                         ...          ...
# 6963        loneliesttimeofyear        mabel
# 6964                myboymytown        mabel
# 6965               oneshotremix        mabel
# 6966              thinkingofyou        mabel
# 6967  thinkingofyoucadenzaremix        mabel
#
# [6968 rows x 3 columns]

# %% [markdown]
# Finally, I will save the DataFrame to a csv file so that I can import it later in another notebook for the data cleaning process.

# %%
pop_lyrics_df.to_csv(path_or_buf='Desktop/lyric_files/pop_lyrics.csv')
